# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
api_key = 'AIzaSyCkqUbsadSkKZz6kRAW562fwY1OJHXEHB0'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# getting channel information
def getting_ch_id(channel_id):
    request = youtube.channels().list(
            part="snippet,ContentDetails,statistics",
            id=channel_id
        )
    response=request.execute()
    

    for i in response['items']:
        data= dict(channel_name=i['snippet']['title'],
                channel_id=i['id'],
                subscription_count=i['statistics']['subscriberCount'],
                channel_views=i['statistics']['viewCount'],
                Total_videos=i['statistics']['videoCount'],
                channel_description=i['snippet']['description'],
                playlist_id=i['contentDetails']['relatedPlaylists']['uploads']
                )
    return data

# %%
channel_info=getting_ch_id('UCbpjEr8lHlnkf1SQ5tnDEYw')

# %%
channel_info
# Out:
# {'channel_name': 'Dream Warrior Pictures',
#  'channel_id': 'UCbpjEr8lHlnkf1SQ5tnDEYw',
#  'subscription_count': '1380000',
#  'channel_views': '608756080',
#  'Total_videos': '683',
#  'channel_description': 'Film Production and Distribution Company. Producers of #Kanam #OkeOkaJeevitham #Sulthan #Kaithi #NGK #Aruvi #Theeran #Kaashmora #Joker #Saguni.\nwww.dwp.in',
#  'playlist_id': 'UUbpjEr8lHlnkf1SQ5tnDEYw'}

# %%
# video id
def getting_video_id(channel_id):
    vdo_id=[]
    response = youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()

    playlist_id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None
    while True:
        response_1=youtube.playlistItems().list(
                                                part='snippet',
                                                playlistId=playlist_id,
                                                maxResults=50,
                                                pageToken=next_page_token).execute()
        for i in range(len(response_1['items'])):
            vdo_id.append(response_1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response_1.get('nextPageToken')
                
        if  next_page_token is None:
            break
    return vdo_id

# %%
Video_Id=getting_video_id('UCbpjEr8lHlnkf1SQ5tnDEYw')

# %%
len(Video_Id)
# Out:
# 684

# %%
Video_Id
# Out:
# ['b_Www6uU-vk',
#  'W-22k_NnX80',
#  'LTEN9p7loFE',
#  'MD57rLYcbZY',
#  'EQc-s2GS1k4',
#  '2JIWNJy_N8w',
#  '0anbxU8AXV4',
#  '8Qc9ZP-ChC0',
#  'pP1kP_9k6NU',
#  'C39Jc32iFAQ',
#  'KTeIDfl8g6Y',
#  'Bwut-Blv9Lo',
#  'nvsEamGPTsY',
#  'TFO_4FFzUbY',
#  'qz1Idbyw8t8',
#  'ZquI0eJO9aI',
#  'UtJcpHAG5Qk',
#  '43QEX5jcrSs',
#  'GNQ0O6FHvpc',
#  '2O_SaVZMNBQ',
#  'm4Sf143_usM',
#  'ZS6YqcQNyNM',
#  'R9Y-UEeKKpw',
#  'bN35FTCtJ3M',
#  'Inv-HSHnXbo',
#  'UmI7zJ3cChM',
#  'pIXPuio7IU0',
#  '13wCMnijM-4',
#  'oVBh9lPqM-U',
#  'q6hA5hR62Ec',
#  'RTtr2RuepHE',
#  'IOAuFJWKQN4',
#  'JEOdEVs_MiM',
#  '3Ga9JWmGEVw',
#  '6_DYTBNogvA',
#  'nWGu1fRji5Q',
#  'KiUFhezU1aE',
#  'bVEO77CwEFU',
#  'IDSUFm3H0h0',
#  'bxRo8Qzio_Q',
#  'mc-_iGoYwAk',
#  '_8TvuB3U5vc',
#  'CiPW84ZNOAk',
#  'bW3lod0KfTg',
#  'OZW5ljRoJsA',
#  'RPQ1-QBUQug',
#  '95cjJ8bxywk',
#  '5N3ta9cKoog',
#  '3XnrZ3TZqck',
#  'AHUTiZEVD98',
#  'e8EoFhN9Lx0',
#  'spVDDqZ3vDA',
#  '7hwol7rMr5M',
#  'DwS3-fsUyJw',
#  'KiPSaeSEaPk',
#  'WOmhivor-KM',
#  'Lq4tL4G7MyQ',
#  'saG_xX9ztuw',
#  'nwpweTFx-5g',
#  'O7UzrvDv_4o',
#  'BJyrIwEI5mI',
#  'RVqG3XQOkvU',
#  'pTqRPWigIdo',
#  'K_xwYxHK9bE',
#  '4u3xwtOvZkU',
#  'IqDEM3ZY2bI',
#  'nV92mTrt31k',
#  'dlsKyWpar7E',
#  'c_l2hMy3JF8',
#  'hacR9grlPjM',
#  'RAcRxZIcxVs',
#  'NreBfJP5STw',
#  '6YQvr7Nmg90',
#  'YaCwvv653Q0',
#  'AXHdKQLY8yI',
#  'o19HUMatf1A',
#  'J4zqpZMhW7c',
#  '3rS0QwWl0PE',
#  'WWLB_hnjvfc',
#  '7UT3I8SFP9Y',
#  'o26tENq7078',
#  'aplbIq4KfDI',
#  'HU5FdEtvYjE',
#  '6rtxN8O-DzQ',
#  'mw9PDQXfXPU',
#  '3glBj9aKq3U',
#  'kzGmwJ7IPoM',
#  'yPYxcz5z188',
#  'aDNJYdNssY0',
#  'XVkV_o29mLo',
#  '11jF8Tjpv5s',
#  'd--3tmeYrP0',
#  'pc73OBKpyYQ',
#  'Ga8BJfZZSu0',
#  'PbTgJEdycdI',
#  '6yauuHxVlw0',
#  'qACzv-Jqgrc',
#  'es0GtAoiTvA',
#  'CAqMZZ44Iqk',
#  'UFlVjlrsULc',
#  '--5jEl743dg',
#  '4myJdue_tec',
#  'jUnQSRPUPYk',
#  'IFJpD1Z73ac',
#  'ipHESU9isOg',
#  '1gQtBhCOZeA',
#  'tnsB1S8kJYo',
#  'qC6p2-6s1Xc',
#  '_LqczMZmK7w',
#  'xTshH3MOszo',
#  '0m7Fp8ZviQE',
#  'ZJX6ibretjc',
#  'sG7YjTmXiFI',
#  'OnsKyP787dQ',
#  'FmhYKTj5XPo',
#  'c2glq8mswH4',
#  'RwM1-2Gbry0',
#  'LzW97N0halc',
#  'iSZipS7cgMk',
#  'nJ7isfwz7kA',
#  'yujEjcy_1j0',
#  'MoBpf-QveFA',
#  'dnV1UK9FXqQ',
#  'uzv-yIiOuK4',
#  'WvWe3mjiwEE',
#  '6doHjZ37QNc',
#  'Nb9HJjjEgtQ',
#  'K1-CcpqvLDo',
#  'gv1mYoV_eA4',
#  'pEOIZyHLANA',
#  '65YRhnw6lHc',
#  'EDSuHuW1m-c',
#  'yfi8fCr92Ck',
#  's8uMzqI0HWY',
#  '4TFWTfbujTA',
#  'Jmgy4lSHRuE',
#  'hqbk376Zjsw',
#  'CaZbTALcv50',
#  'fQG5W39XDgA',
#  '8jGLKKd3lRw',
#  'Y1GXlAsn8Jk',
#  'nMrsI3cwP88',
#  '3TDxIbw8wtQ',
#  'Kt5uJsjZKyk',
#  'SJkg3-e3pPA',
#  'A2PT65Zk8Wo',
#  'VAHuQBVxjXQ',
#  'Xa7DLUJrOUg',
#  'y_ckuIDgeDk',
#  'MuDKH5v5NEE',
#  'xDuE9BDEqwI',
#  'IxVXeJ5x6PQ',
#  '_J6md7ZdaTU',
#  '-6DBpkdty70',
#  'Z44q0Oj-ymk',
#  'xpfithNyMSY',
#  'iLx4kIMCKxE',
#  'P36t8whCanE',
#  'a4vTofKn-k4',
#  'h03IiWelcIM',
#  'XT2qsFonL40',
#  'Mi048RPIyUc',
#  'pEM5iKwr4W4',
#  'xSMB5hjmYqM',
#  'a_A-A0BkR_w',
#  'A8cg-UsTxY0',
#  'VKFqxeaf_Do',
#  '-PF--5ZFF7c',
#  '0iXUAjLMFig',
#  'J-eJFDFetsI',
#  'HanjjxN2g2E',
#  '-EhAS0Tnfno',
#  'b8cBG_UK1xg',
#  'ug9ZLvwftFY',
#  'EIpLxOjmiCU',
#  'C9hBiQFhznY',
#  'CrQxh3Sfpg0',
#  'FXCtlMgRK4w',
#  'HiX54v3lzPs',
#  'toc9TGfFXwY',
#  '881dqXSLk5U',
#  'zlpt40PDtpo',
#  '8Jem6Z-7FAQ',
#  'mRzRbTRIlUI',
#  '8jiNMHqtk14',
#  'O-6UDdc0V_w',
#  'a74HxLUNeIc',
#  'xi8xBblaTK4',
#  'DXvC9glJmh8',
#  'AGFiTUfDtSQ',
#  'nRITxmuwmqA',
#  'dFbW-LKKarU',
#  'vTe-NdfyXT4',
#  'fUwMWzdeXyc',
#  'TQgkBgCeYHM',
#  'gmitAjpNwDI',
#  '59vQiOMchCw',
#  '4HZupcaKvEY',
#  'b91rAtYskOA',
#  'U8tfeI1iy0U',
#  'IKTlQypcIOA',
#  'cJPqYx0JWKw',
#  'w8x5ki0C2Yo',
#  '04ZdAEAhrhU',
#  'y8EvuF1DPys',
#  '72zE3kEmrlE',
#  'FmJQ9wpWOBA',
#  'vx91Ox86Ook',
#  'M_wigAk44Dc',
#  'CGjMpT--IyU',
#  'l2M2Vo-nIvQ',
#  'GR3MlbTVYVk',
#  '-VDfV6mjO_I',
#  'p4Xgxvwuiuk',
#  'RNXNS430i10',
#  'qr9N7INRKho',
#  'gwZt4QwlUKc',
#  'XKC3DydeV6k',
#  'EjQ9WiwbipY',
#  'V-puu8Xg9sw',
#  'RSbIQ38QmBk',
#  'UkTdbdSKo-8',
#  'eUoPzjMQwTo',
#  '4BahFaXn0qo',
#  'hcnf7A1pTGU',
#  'YDZnHMdEeDQ',
#  '3C87coqxKm0',
#  'ZapmyYiL_OU',
#  'VoBZ3k3WOf8',
#  'T_z6PVoed1o',
#  'aTTFjIeKlu8',
#  'Ix5LwFUHzy8',
#  'gNHpeC4eW6k',
#  'xnDjLbVqCsc',
#  'hrBvAPYBYAY',
#  'EVWp13mp_bQ',
#  'fT0OU_Kvu3Y',
#  'vOYax9BwJ6Q',
#  '_0nYPHs3ESE',
#  'M2qR9NxFyz0',
#  'YcBsh3CXGZg',
#  '62Lo4fAjasc',
#  'QOGuDHkXbg8',
#  'mGsK-E4KqCs',
#  'hM6nN13pzfU',
#  'ZMr92srM340',
#  '-EI6JFocDxo',
#  '1tEt-WNnK00',
#  '04Sx3RAMhjA',
#  'XwkiXkGhWEw',
#  '278hRqONksc',
#  'eelhGOfPMgA',
#  'jYVebglkWdM',
#  'dnZm4AgLaO8',
#  'aChKsRXLepg',
#  'tc9pxlAs5aM',
#  'iA6JC4L6XSU',
#  '94Q6P9jflTc',
#  'JMWVk6lMNKc',
#  'TN5U3XoPTFw',
#  'XVZfSkDU6oQ',
#  'qz_XrbWVTw8',
#  'hmWkUi6528E',
#  '0gatFZLGEy0',
#  'MYSjKBoiSnI',
#  'WwtkTqOKRgQ',
#  'XUWVJgN9hk0',
#  '0XCxa35UBgw',
#  'nDIFhptUIas',
#  '2P-FnnfiJq0',
#  '5nIyicpcd50',
#  '-KpwnaNjyco',
#  '3XPbRWuK9-8',
#  'Ci0Jcvox0sY',
#  'qQ_rO6Qbcj4',
#  'hAvnDMjcKic',
#  'FkwdmHsNSOQ',
#  'xmzncGacgHw',
#  'eWzUADDGl6E',
#  '3e9SD0T5O0U',
#  'A820g1mhGl8',
#  '0DZqDFl-0xs',
#  'YqEfdqjP7Jc',
#  'cKIjQ-KBsKQ',
#  'h1e599s8GWs',
#  'e9ykWCBAdbY',
#  'mxaN7q95rWE',
#  'xc4a52ZiGog',
#  'vd8GeFmMszE',
#  'wuDP4Xe50_g',
#  'rc5Vsk7L8Rk',
#  'IAtFyq6FsFI',
#  'fVkhMwXSEns',
#  'ADOpT5ChLbI',
#  'U3xJlYD9gjc',
#  'Z_NhUzubhGY',
#  'B7RPDOOKLFM',
#  'C4XZaKykhC4',
#  '-c7rx1zjtW8',
#  'IzWwqtJQINw',
#  '8JdpwtkFML0',
#  'hCRKj0bcFkc',
#  '9mTY0A3BQ4o',
#  '0CBqgxCG2II',
#  'nWZRETmu2_w',
#  'JJcWr5ecFho',
#  'VwtzGaO1QYw',
#  'ZlTU7vMIgis',
#  'ospwLcZCNEM',
#  'kAUZxFwmTg8',
#  '6cWW1_3Cb14',
#  'A7qy41s07Aw',
#  'MDoDwfPnSEI',
#  'EYsEZ-sEii4',
#  'yPpHKAYuVTU',
#  'tngsVP3nr3Q',
#  'dHzbXlOv5N4',
#  'zQKjrAIxZRw',
#  'fA5n8Kx6unM',
#  'BjW2RdJ_Ui8',
#  '4gohbdWDVGE',
#  'qGa4XoVLRLE',
#  'C0NXMbm9wDg',
#  'dbsUTBILSNI',
#  'dxh10-k7r0k',
#  '0x_k0T1PkSY',
#  'WbNjPX3kD3Y',
#  'z3U6ZMfpWVE',
#  'DrPqxtWJ2NA',
#  'Au5gNjCQ5HE',
#  'Y69tJBagsB4',
#  '3iNgHzV3xMI',
#  '554-CauKl6Q',
#  'TbzTAyf5lQ0',
#  '6LIlJXCt_xQ',
#  'PDfSzvcAUTQ',
#  '-m-RbdLGmP0',
#  'eetwaIlXPK0',
#  'ImN3AhED9eM',
#  'pGoKroYSzQ4',
#  'c9zEh4MmCEM',
#  'TDa6Q5kcBK8',
#  '1HbbatdjOvc',
#  'k3zjvQSWaNw',
#  'MBtbyHdepRs',
#  'OXggGgN1wlU',
#  'jmdkor3bJjE',
#  'ObPo_08WmMM',
#  '3LNY3Nx2-ks',
#  '6T1b4d2DQkY',
#  'cPERWRxHNhY',
#  'Mmam_7ggVDU',
#  'MpuE_XLXrZM',
#  'owM-cE1jAMM',
#  'tORAURU-P0g',
#  'UUmSRPMjSoU',
#  'm6RloxkJS40',
#  'st4euv38Vn4',
#  '0BK76iP5b9o',
#  'sepMkr9jV94',
#  'cWby1dHCSIo',
#  'qagke26BEg0',
#  '0iPyqMEHYqU',
#  'TzZAge994uI',
#  'FJ4IDK1kRvg',
#  'xS2oX_KZXEU',
#  'yqJNo-9Dx40',
#  'joDV-PMiePw',
#  'yLGXWATExUM',
#  'xH_akedEmsI',
#  '7vxyZeLi8N8',
#  'xQgttq7F48c',
#  'nWi_x5q-J9w',
#  'vKxpevyvCHY',
#  'fgt2H5Jxw_U',
#  '7p7BJXi-wPU',
#  'FlKkgSphVD4',
#  'tJStfTpr-Yw',
#  'pk_-EniMFDM',
#  'vxG7ro2R8Pw',
#  'JKzKd2_Q2LU',
#  '2wkhzGqX_dI',
#  'AZ7ylgbSMbs',
#  'xk-dwq8jFRg',
#  'kooaXrYpDXc',
#  '00t_izgwlJE',
#  'WsfX9UdqU48',
#  'rP17AM6DBd8',
#  'BcI9k5dQY1A',
#  'I7utqB8oi9o',
#  '-995kI-pXJk',
#  '6lSQsR8QpC4',
#  'loK8hwmog68',
#  'BIyG_O11QE4',
#  'U2eeDApKKWg',
#  'hb410-RKCXs',
#  'fX7MvUl1krs',
#  'H4ge-RZVnGg',
#  'MfXDf637KSo',
#  'BS8rmD-aYn0',
#  '-3gWNzvYZOE',
#  '_kCcyUFXOT0',
#  'bYtMdnHcg24',
#  'dbAGIsycBAY',
#  '5hIkUj7hE4k',
#  'ie0FvMOSegQ',
#  '5zdGtf9NOx8',
#  'aSCMwWBCVI4',
#  'F_3bIHzV0Mo',
#  'IURXtNs0dVM',
#  'KQhbATry-UE',
#  'JJW6MUnZL9w',
#  'n5N4m_YwNcQ',
#  '8oRUDobHplY',
#  'cS3O_TU7OqI',
#  'p6zR_blgt_4',
#  'bRpLQCav2JU',
#  'nfr2hwlV0gg',
#  'ZKsDacoV6KE',
#  '6jeEkMtyDPs',
#  'ItMHp_nR1hY',
#  'miqlSQxKmFs',
#  'H7thS8nrdO0',
#  'pk0DtSXlaX0',
#  'zdyDweoXHRM',
#  'kX9u4FEhY7w',
#  '-qO0fdJSz7s',
#  'oVVRgmWqSMM',
#  'QgtO1ezs1Bk',
#  'RLJlbAwn8YU',
#  'kUh4JVTh5Rg',
#  'nNS1Igi3GOg',
#  'NQCzE2d9E_I',
#  'vA--DjGR6SA',
#  'jWAI26Fte5A',
#  'YdrJmqXZJ4Y',
#  'cIk0dUfEKDU',
#  'YVzctlt8_RU',
#  'wF85sy5GOTc',
#  '_OhY6ebztbE',
#  'PtPQITs7JqA',
#  'xSPTjLKm1bU',
#  'fkBbFkhGTds',
#  'HlxobiKs1sw',
#  '1MmdpnO18ZU',
#  'lKnMsWPabbk',
#  'VgoU9LaSSew',
#  '0PC1uaCXKAU',
#  'kSQd9YwjRp4',
#  'BmcqiooMLUs',
#  '-sBEqEODm-M',
#  'WY12sD4Rm-I',
#  '0NrJyVplPcI',
#  'yNenFuM-F5w',
#  'S1nkO8Tz0sA',
#  '9RYc_DC4sqA',
#  'GktPIXOBdaM',
#  'ST7Iy88xVos',
#  '9HHrIK3fj6M',
#  'Hft3KG9ZcZ8',
#  'PISQ_2TTmX0',
#  'rcgHRA3Dcr0',
#  'ncS91kjTADw',
#  '9OiwD69IVcg',
#  '4pmctzM7Syk',
#  'hv_SBLDMxsg',
#  'kfgHu_fjwKM',
#  'yReNQIHpobw',
#  'ROg9RUUl2wU',
#  '2xuRpinwZNk',
#  'KWcfDVkq7II',
#  'O70iv2VzEag',
#  '3XIs4TpPuQw',
#  '0s8ENYg0bxs',
#  'mOLhd-vr80U',
#  'dK1R9FEoWYY',
#  'm2rCfdwipBY',
#  'A82NXUM0esc',
#  'mFzMVX5Ne7k',
#  'rRvzkGpzG0I',
#  'jr9DmwcsZKc',
#  'vbG93mhRN0k',
#  'jZ6kPxPXhHA',
#  '0dEUOmc78X4',
#  'ZANjOfjTRSk',
#  'VPzH8Ffibi4',
#  'MLSCx7CNsHY',
#  'fvkPCKiC6ag',
#  'VQ3c4JOv-84',
#  'DdR0W_O-0Bw',
#  '0_WzqBUbGHY',
#  'PAKgbdp3T64',
#  '9jWy4E3RqK4',
#  '6CBOJ0u9HoE',
#  'bjf6IuzGvC8',
#  '93Zwa3tERrk',
#  'rlsuymty4vg',
#  'Omdrfy-aIro',
#  'oQxGtBmpTv8',
#  'e8MeZSfhIZI',
#  'DXjz5AkT5qs',
#  'pubL_hTaTbE',
#  'LqQCY0scLf0',
#  'yDLNzygjv1U',
#  'ackbdNeLbLU',
#  '_tAE6NtDz4M',
#  'ZCxumqSYaw4',
#  'TS_wpgzBlY8',
#  'DDgN3GXik2o',
#  'K91FXbjUx8k',
#  'd5RxfB3E6xE',
#  'GuYGkrShbYE',
#  'uctocdwws-s',
#  'N_fZ92S89GY',
#  'GupyXe1s3vk',
#  'xKXzVpPIHwc',
#  '_Sb1mY1V4c8',
#  'w-KdeE2v96o',
#  '4QC-xQwldcQ',
#  'q2vSn_4qQpQ',
#  'NEWdfa6hYvc',
#  'UqR_xhkBt7c',
#  'RGg3wgKpIAg',
#  'kd-x5MVRW7g',
#  'fouPddcQnqc',
#  'Qj6hvD8J7y0',
#  'Ec4caG6AZrI',
#  'U5lrQxbG3Iw',
#  '6v_0Uy67Ris',
#  'RVHGDn7j3AY',
#  'uoHhk1zh860',
#  'Dr3auNDoz0w',
#  'CuT5tfiC6bc',
#  '3tXCPYtb1PI',
#  'cz_yZiOXgD4',
#  'ongF_2Ot4IE',
#  'm1WuFz7e75w',
#  'vZtycUr5drk',
#  'EWp7eDbJSCA',
#  'y9J3M48p6Zg',
#  'FVTwJCvSDEY',
#  'A8AbWotG_gk',
#  '_MMKNhHShQE',
#  'mI44BbPV4fk',
#  'qWGYtRKQs04',
#  'A32yLrkcQP8',
#  'TNKqrMCYPRU',
#  'vruZDgdiXN8',
#  'NsoRIcNdAh4',
#  'VOw1RYZFU_Q',
#  'IyMFW4hchwU',
#  '2kAsNn9kP28',
#  'jP_TBrBjebo',
#  '1fQN2X1BnqE',
#  'SjAcvpfILOs',
#  '3EH1vw7p75M',
#  '2l0K97-7grk',
#  'xW4QVV7hqL0',
#  'q-y6cwwwZGs',
#  'xKajllpBd08',
#  'tP_dh_s27iw',
#  'VbHf0vl3LvE',
#  'pxjK-9UkMbA',
#  'w3BxbkbPlEI',
#  '6ZoyTalzrK4',
#  'BC6UOXk4lX8',
#  'eQdHOJSq6HE',
#  'g79CvhHaj5I',
#  'Py13Ic_2wVk',
#  'Imd1_Rapnvs',
#  'kzgvvcidxq4',
#  '0KowwXsjPFs',
#  'AlAX_fP-5J4',
#  'l16IlPEWpL4',
#  'fug6Db-q4e4',
#  'pzoYIX1mFBI',
#  'c1ZhwHQEEho',
#  'e-rv0RjUkGI',
#  'AQSMGTLnDlk',
#  'K9-olvIfNnE',
#  'VFqe7_MdThQ',
#  'XVsfbIz8ZaM',
#  'mC9e7ywzvnU',
#  'KPndTU16k7c',
#  'QYAmpAtRUNo',
#  '1Pj5qc9e7Pw',
#  'tNYzS_w-XRI',
#  'gyYmNvhubFk',
#  '83NWgiPmQGs',
#  'aO-ZHocQV1w',
#  'y8igbV7ouuk',
#  'jjVAytvq7OU',
#  'okMeU7TBsWg',
#  'Mi-bHecYksM',
#  'YbCJDzrvpms',
#  'FiX3hCsTKFM',
#  'tqh1qf9ep0Y',
#  'Xd6WYjwD9yk',
#  'VoE0hH7nfF8',
#  'Ky_eZY8KHrI',
#  'Tl9SqlU9FHg',
#  'Q9qOAf5n83M',
#  'Wdy-YCw0syU',
#  'jgYYxs_d_bo',
#  'ak5Zb-1g8ME',
#  'AVvtK--oh1E',
#  'M54L0VtqIew',
#  'QbpcJRz6u1g',
#  '6VGYgzeOl5I',
#  'pZytlBXpfLk',
#  'HzlXqzM1eoo',
#  '8z5fn88nBNg',
#  '70nwRXS68oU',
#  'SfO9HFYqzmM',
#  'w_SA25wMtb0',
#  'xjFKfAudCOo',
#  'EVQJN6ATm5U',
#  'D3CnL6eDz2I',
#  'Ptp82aOTrXM',
#  'lyNbM7JMXV8',
#  'KUWd6XmRCMU',
#  'MP_H_HU2OvQ',
#  'NtXSDocjP88',
#  'i2ZdVirvUsk',
#  '9JfHGxk9JCs',
#  'tQSIfuLLtIc',
#  'yxcfCP3UJS8',
#  'AXdWCB6Yn6I',
#  'fOS6wa9iZ5A',
#  'h_k-_NHRZxI',
#  'kVUzPukhQkU',
#  'xiCo0HTfXlE',
#  '3EjyhCFmaUE',
#  'UqMDKUjxThc',
#  '-ObjF5_67GU',
#  'gJz35RLd810',
#  'iWt8J2NPqJc',
#  'ae_T7WZ1NrQ',
#  '0ABHE6moHtw',
#  'NVIs4DigOg0',
#  'ftOEAhxAOaY',
#  'hW_V81XOBB8',
#  'rcaK_gd3kLU',
#  'i5xjx2sie8Y',
#  '-Hwtqgb-OQA',
#  'gAqmHVYYTRY',
#  'qkbqLor6FeI',
#  'wGFxGKt-juY',
#  'Q4om0eGz84E',
#  'eP4rkjxuD4Q',
#  'l4Yi08Vd8gI',
#  'DRPfKFFHt0w',
#  'KNQ_b_MSw74',
#  'hzyjluV6xW4',
#  'z3hRGsfZknU',
#  'M4F9Rg-8fJY',
#  'xiv6QCNMzlo',
#  'rilkXyjKPVc',
#  'aXcepkKSSaQ',
#  'TaUiA1QbuHk',
#  '2wQKxssF8rc',
#  'APjqXVhuZJk',
#  'TuhauKDfXfA',
#  'rRo5u6QjfxA',
#  'NfTvcxc1XVM',
#  '5EZs1zWYIRk',
#  '0j-_LOCBlBk',
#  'thr816BCP1Y',
#  'se5sEVK4Y0s',
#  'qIrlj3ssrY4',
#  'VwAerfm01RI',
#  '5uxoGJ3mV4Y',
#  'GZorQY7U96M',
#  'g0R_pCkHSf0',
#  '5Q2UK3LcC20',
#  'qCYLQ2l1SxI',
#  '9Ky6R1i3rXs',
#  '4xr59w5r6Hw',
#  'yCIXXMJyu34',
#  'CRh1DjGpoFc',
#  'SmMQEAV-IJ8',
#  'fF8jcL2g_IU',
#  'SZxMwfAsykc',
#  'nyVn5t7bVto']

# %%
#getting video info
def getting_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part='snippet,ContentDetails,statistics',
            id=video_id
        )
        response=request.execute()

        for item in response['items']:
            data=dict(Channel_name=item['snippet']['channelTitle'],
                    channel_id=item['snippet']['channelId'],
                    video_Id=item['id'],
                        title=item['snippet']['title'],
                        tags=item['snippet'].get('tags'),
                        thumbnail=item['snippet']['thumbnails']['default']['url'],
                        description=item['snippet'].get('description'),
                        published_date=item['snippet']['publishedAt'],
                        duration=item['contentDetails']['duration'],
                        view_count=item['statistics'].get('viewCount'),
                        likes=item['statistics'].get('likeCount'),
                        comments=item['statistics'].get('commentCount'),
                        favourite_count=item['statistics']['favoriteCount'],
                        caption_status=item['contentDetails']['caption'],
                        definition=item['contentDetails']['definition']
            )
        video_data.append(data)

    return video_data

# %%
video_details=getting_video_info(Video_Id)

# %%
video_details

# %%
# getting comment information
def getting_comment_info(video_ids):
    comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                            part='snippet',
                            videoId=video_id,
                            maxResults=100)
            response=request.execute()
            for item in response['items']:
                        data=dict(comment_id=item['snippet']['topLevelComment']['id'],
                                video_id=item['snippet']['topLevelComment']['snippet']['videoId'],
                                comment_text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                                comment_author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                comment_published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                        comment_data.append(data)
                
    except:
        pass
    return comment_data

# %%
comment_details=getting_comment_info(Video_Id)

# %%
comment_details
# Out:
# [{'comment_id': 'UgwhcVlFeDjKUPNPmlZ4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': '❤❤❤❤❤❤❤❤❤❤❤🎇🎇🎇🧨🧨🧨🧨🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥',
#   'comment_author': 'Sri Ram',
#   'comment_published': '2023-11-10T04:08:18Z'},
#  {'comment_id': 'Ugxd6yiQA5HU7Fo-CR14AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Set scene! ❤',
#   'comment_author': 'Vizag Thope',
#   'comment_published': '2023-11-09T17:32:42Z'},
#  {'comment_id': 'Ugw5U4f7O4cQ1nWEMmF4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Karthi is a greatest actor and nobody can act like him. <br>He is a number one super actor. ❤❤❤❤',
#   'comment_author': 'velu murugan murugan',
#   'comment_published': '2023-11-09T16:58:59Z'},
#  {'comment_id': 'Ugw938Q-MdR9TcUMUEt4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'I like karthi as a Raja Nayak',
#   'comment_author': 'velu murugan murugan',
#   'comment_published': '2023-11-09T16:55:40Z'},
#  {'comment_id': 'UgwyFjMY-rppwdmcBWh4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Title card super Golden star ⭐⭐⭐ Japan movie la vantha nalla irukkum',
#   'comment_author': 'Deepan deepan',
#   'comment_published': '2023-11-09T16:34:03Z'},
#  {'comment_id': 'Ugw1Cn0dmQCbVpyH3Gd4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'We love karthi anna ❤️❤️❤️',
#   'comment_author': 'jayasivasai',
#   'comment_published': '2023-11-09T14:26:13Z'},
#  {'comment_id': 'UgxMwewbWERVmeKA-zV4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'This film may be huge disaster',
#   'comment_author': 'fayaz meeran',
#   'comment_published': '2023-11-09T13:46:39Z'},
#  {'comment_id': 'UgwsyTzj_COfzMKdxd94AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Form thalapathy fans all the best the movie will be super hit',
#   'comment_author': 'Abhiraksha Abhiraksha',
#   'comment_published': '2023-11-09T13:24:07Z'},
#  {'comment_id': 'UgyHd7DFtW46jK3Bkrx4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Karthi Anna All the best from telugu fans ❤❤ Waiting for the blockbuster hit 🎉❤❤',
#   'comment_author': 'Lucifer',
#   'comment_published': '2023-11-09T13:23:34Z'},
#  {'comment_id': 'UgwfNSUw8NZyb1Ew-Ip4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Karthi Anna 💞💞💞💞💞💞',
#   'comment_author': 'Elamaran Iniyan',
#   'comment_published': '2023-11-09T13:06:22Z'},
#  {'comment_id': 'UgwyoSinTSWUwTDJ-0R4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': '🔥🔥🔥🔥😍',
#   'comment_author': 'Thomaskutty John Philip',
#   'comment_published': '2023-11-09T13:05:47Z'},
#  {'comment_id': 'UgwE2iM9jsHutcD8XKJ4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': '<b>karthi is not simply acting,he is just living in that character💯🔥</b><br><br><b>pure goosebumps overloaded😻</b>',
#   'comment_author': 'JOJO Pranksters🎥',
#   'comment_published': '2023-11-09T13:04:30Z'},
#  {'comment_id': 'UgyE5dshRLlpevnV7LN4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': '🎉🎉<a href="http://www.youtube.com/results?search_query=%23japandiwali">#japanDiwali</a> 🎉🎉 🔥',
#   'comment_author': 'Naveen Kumar',
#   'comment_published': '2023-11-09T12:38:36Z'},
#  {'comment_id': 'UgxXAzHqIbNNZEbrO2p4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Annaa 😍',
#   'comment_author': 'Krishna Pradeep',
#   'comment_published': '2023-11-09T12:28:42Z'},
#  {'comment_id': 'UgyzBsimhTGhc3eVPzR4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Revolutinary CheGuevara ✊️🚩❤️',
#   'comment_author': 'PraveenKumar',
#   'comment_published': '2023-11-09T12:27:23Z'},
#  {'comment_id': 'Ugzuny-YUzGQoErz4F54AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': '<a href="http://www.youtube.com/results?search_query=%23utube">#utube</a> | <a href="http://www.youtube.com/results?search_query=%23love">#love</a> | <a href="http://www.youtube.com/results?search_query=%23emotional">#emotional</a> | <a href="http://www.youtube.com/results?search_query=%23romantic">#romantic</a> | <a href="http://www.youtube.com/results?search_query=%23trending">#trending</a> | <a href="http://www.youtube.com/results?search_query=%23tamil">#tamil</a> | <a href="http://www.youtube.com/results?search_query=%23trendingvideo">#trendingvideo</a>',
#   'comment_author': 'Utubekaaran',
#   'comment_published': '2023-11-09T12:26:53Z'},
#  {'comment_id': 'UgzS5jdicj8-ivPJvXl4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'ஜிகர்தண்டா டபுள் எக்ஸ்',
#   'comment_author': 'Remomani Mani',
#   'comment_published': '2023-11-09T12:20:20Z'},
#  {'comment_id': 'Ugxtjq2lYBSEAl4mUCt4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Bhomma heroine😂',
#   'comment_author': 'The expert Waterman',
#   'comment_published': '2023-11-09T12:19:26Z'},
#  {'comment_id': 'Ugwu72b8UDgxEVQi6_R4AaABAg',
#   'video_id': 'b_Www6uU-vk',
#   'comment_text': 'Happy to watch Japan in Japan🇯🇵🧨🔥',
#   'comment_author': 'tlm tlm',
#   'comment_published': '2023-11-09T12:18:29Z'},
#  {'comment_id': 'Ugw0eRNxqJDCVC0PxYF4AaABAg',
#   'video_id': 'W-22k_NnX80',
#   'comment_text': 'Karthi mama all the best for japan movie ❤❤❤❤❤❤❤',
#   'comment_author': 'vasantha kumari',
#   'comment_published': '2023-11-09T22:02:49Z'},
#  {'comment_id': 'UgxMQwKhzhAtxaeZyDZ4AaABAg',
#   'video_id': 'W-22k_NnX80',
#   'comment_text': '🤍',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-09T12:06:05Z'},
#  {'comment_id': 'UgyAvNma7IkJo9HCPb14AaABAg',
#   'video_id': 'LTEN9p7loFE',
#   'comment_text': '⚡',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-09T12:05:38Z'},
#  {'comment_id': 'UgyT6uxoj1X3p1xov6B4AaABAg',
#   'video_id': 'MD57rLYcbZY',
#   'comment_text': '❤♥️♥️',
#   'comment_author': 'Thomaskutty John Philip',
#   'comment_published': '2023-11-10T02:09:04Z'},
#  {'comment_id': 'UgwLxcknn3h4u4iGcm94AaABAg',
#   'video_id': 'MD57rLYcbZY',
#   'comment_text': '💛',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-09T12:05:13Z'},
#  {'comment_id': 'Ugwr23AL0RJrwTdzkwh4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': 'WHAAAAAAAT!!!😂😂😂😂😂😂❤',
#   'comment_author': 'Contessa Shadeau',
#   'comment_published': '2023-11-09T23:01:05Z'},
#  {'comment_id': 'UgyknELdVkUwI4ppxoh4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': '❤',
#   'comment_author': 'Sanjay Ks',
#   'comment_published': '2023-11-09T15:50:18Z'},
#  {'comment_id': 'UgxxNSTjt6N2q6x9mUF4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': 'I am waiting ✋️',
#   'comment_author': 'Raisah',
#   'comment_published': '2023-11-08T15:19:21Z'},
#  {'comment_id': 'UgzhX6UY__jl1GISmT14AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': 'I can’t wait',
#   'comment_author': 'NADHER AASIFE',
#   'comment_published': '2023-11-08T13:52:15Z'},
#  {'comment_id': 'Ugy0HsPoEG2Of9tuJSF4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': 'waiting 🔥🔥💥🔥💥🔥💥🔥💥',
#   'comment_author': 'Naveen Kumar',
#   'comment_published': '2023-11-08T13:04:12Z'},
#  {'comment_id': 'UgwljKos-oQPqOU9JlJ4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': '❤❤❤',
#   'comment_author': 'Mahi Mahendran',
#   'comment_published': '2023-11-08T13:02:08Z'},
#  {'comment_id': 'Ugy7AEg7CsD4wnVMRFF4AaABAg',
#   'video_id': 'EQc-s2GS1k4',
#   'comment_text': '⚡',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-08T11:45:36Z'},
#  {'comment_id': 'Ugzjy596u-QRDdhl3Ux4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'karthiiii 😍😍😍😍',
#   'comment_author': 'Venugobals',
#   'comment_published': '2023-11-09T13:28:53Z'},
#  {'comment_id': 'Ugx3tY6IDZbygcK2hfN4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': '👏🏻👏🏻',
#   'comment_author': 'Alwin Benjamin',
#   'comment_published': '2023-11-09T03:20:55Z'},
#  {'comment_id': 'Ugx4dTGK7xeVDwrH3TN4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Kadisiya oru muttru puli vachutiga andha controversy ku. Eppo purithu enn apdi sonniga nu. Apdiya andha ameer anna problm ah solve pannalum nala erukum',
#   'comment_author': 'prithvi raj',
#   'comment_published': '2023-11-09T02:17:11Z'},
#  {'comment_id': 'UgxZCv_P-e4swi0p32V4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Shivakumar payen Rs.5000/- ku job ku ponaangla? Okay right-u.. Idhu kadhai alla Nijam. Idhuku avuru fans yenaku dislike panuveenga nu thereyum but onea onu solrean yelaarum vungalku ena theavayo adhu matum eduthukonga just because you like someone nu yelamea nambhadheenga.',
#   'comment_author': 'Dharani G',
#   'comment_published': '2023-11-09T02:04:43Z'},
#  {'comment_id': 'UgzajEK8HfWowah39cN4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'What is happening here',
#   'comment_author': 'Naveen Daavse',
#   'comment_published': '2023-11-08T18:57:30Z'},
#  {'comment_id': 'UgxJ2gg4izZNhUOwvp14AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=2JIWNJy_N8w&amp;t=4m53s">4:53</a> Life Changing moment Train stories <a href="https://www.youtube.com/watch?v=2JIWNJy_N8w&amp;t=5m55s">5:55</a> Karthik sir about his father',
#   'comment_author': 'varun prakash',
#   'comment_published': '2023-11-08T10:35:56Z'},
#  {'comment_id': 'Ugz36lxj3JOZvx-4cuV4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=2JIWNJy_N8w&amp;t=4m53s">4:53</a> - life changing movement',
#   'comment_author': 'SHIVA PRASAATH',
#   'comment_published': '2023-11-08T08:17:27Z'},
#  {'comment_id': 'UgwVWW_Xtn-hTQFlvzt4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'You like telugu audience a lot no sir<br><br>Karthi - oka chinna katha chepta vinu - 12 years before a boy wrote an unique story and showed to his parents and thought they will love and appreciate him but sadly they teared it n thrown in dustbin but his neighbor aunt came n told the story is very good <br><br>When yuganiki okkadu released Tamil audience didn’t accept that time but we telugu audience loved the movie and made a biggest hit at that time so he told he loves telugu audience ❤',
#   'comment_author': 'Chakradhar Reddy',
#   'comment_published': '2023-11-07T19:36:30Z'},
#  {'comment_id': 'UgzZ12imHLw1hMOpv5x4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Ameer marathitinkala thambi',
#   'comment_author': 'Sureshkumar T',
#   'comment_published': '2023-11-07T18:17:44Z'},
#  {'comment_id': 'UgyhFYvNkuGA5Ednq7F4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Wow what a orsem speach from karthi mama hes really a greate men everyone must follow what he said in this audio launch❤❤❤❤❤❤❤',
#   'comment_author': 'vasantha kumari',
#   'comment_published': '2023-11-07T18:01:22Z'},
#  {'comment_id': 'Ugy0LiyhSDyTNleBYpR4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Kutty story mass anna❤❤❤',
#   'comment_author': 'Deepan deepan',
#   'comment_published': '2023-11-07T17:24:40Z'},
#  {'comment_id': 'UgwKXtoQcSqeUGMNRj94AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Karthi Ann kaithi 2 waiting',
#   'comment_author': 'Ajith Ajith',
#   'comment_published': '2023-11-07T16:30:39Z'},
#  {'comment_id': 'UgzWO_7Krfo4wIxUNSl4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Karthi Anna big fan 💞💞💞',
#   'comment_author': 'Elamaran Iniyan',
#   'comment_published': '2023-11-07T16:18:16Z'},
#  {'comment_id': 'UgzcnkEWQUYh3Lv71tB4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Speech Telugu dubbed please',
#   'comment_author': 'Mahesh sirnapally',
#   'comment_published': '2023-11-07T15:04:57Z'},
#  {'comment_id': 'UgxRfx6euttdXw1YY3d4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': '<b>how many karthi fans are here🔥?</b>',
#   'comment_author': 'JOJO Pranksters🎥',
#   'comment_published': '2023-11-07T14:45:54Z'},
#  {'comment_id': 'Ugx6EyySvbuPXD-ynlN4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': '❤ litteraly best speech',
#   'comment_author': 'Ragu Raman',
#   'comment_published': '2023-11-07T14:09:44Z'},
#  {'comment_id': 'UgxBARToe_FU9LmD8-54AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Director padam edukkurathum makkal rasikkathan, avanga enna chumma luluvaika padam edukkurangala.. appadi akkarai irukkavanga edhukku directora nambi poi avara imsa pannanum, neengale nalla padama edukkulamala',
#   'comment_author': 'NNAACC N',
#   'comment_published': '2023-11-07T14:00:53Z'},
#  {'comment_id': 'Ugz71PYBKon_04Wydt54AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'Karthi anna😍😍😍',
#   'comment_author': 'Vignesh',
#   'comment_published': '2023-11-07T13:55:50Z'},
#  {'comment_id': 'UgxjB4Q6T_MjbKcaz6V4AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'கார்த்தி அண்ணா❤',
#   'comment_author': 'BOOK CRACKERS',
#   'comment_published': '2023-11-07T13:03:06Z'},
#  {'comment_id': 'UgxPGiwG_2r8XqDTyB94AaABAg',
#   'video_id': '2JIWNJy_N8w',
#   'comment_text': 'What karthi talk about Telugu fans any idea 😂?',
#   'comment_author': 'DR. V',
#   'comment_published': '2023-11-07T12:20:34Z'},
#  {'comment_id': 'UgxZ5W7pn_yYSzn0jU14AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': 'Suma akka nega always semaiyaa panringa, and unga counter and timing elam bayangarama iruku .... Tamil la suma akka mari oru female Host illa . Telugu audience kooduthu vachavanga :',
#   'comment_author': 'Fiyas Ajmal',
#   'comment_published': '2023-11-08T19:01:49Z'},
#  {'comment_id': 'Ugz1V-i0b4V_mz2dAXV4AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=0anbxU8AXV4&amp;t=15m28s">15:28</a> 😅❤️ <a href="https://www.youtube.com/watch?v=0anbxU8AXV4&amp;t=22m15s">22:15</a> 😅❤️ funny and friendly interview',
#   'comment_author': 'Anish Karthik',
#   'comment_published': '2023-11-07T16:28:14Z'},
#  {'comment_id': 'Ugx4_nG376Y3Hk0gUdV4AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': 'Look at his Telugu fluent ❤',
#   'comment_author': 'Gopi Gemini',
#   'comment_published': '2023-11-07T15:17:11Z'},
#  {'comment_id': 'UgzegMVInYpb7NtzTU54AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': '<b>how many karthi fans are here🔥?</b>',
#   'comment_author': 'JOJO Pranksters🎥',
#   'comment_published': '2023-11-07T14:45:47Z'},
#  {'comment_id': 'UgwsGIJd9IWgF0c7ndV4AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': 'Karthi Anna Mass ❤',
#   'comment_author': 'Magesh kannan',
#   'comment_published': '2023-11-07T14:06:13Z'},
#  {'comment_id': 'Ugz6okPrGIw06vXJX_94AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': 'Okkasari Dilli Digithe ey Leo lu undavikkada',
#   'comment_author': 'arjun n',
#   'comment_published': '2023-11-07T12:31:49Z'},
#  {'comment_id': 'UgyltYARM0hihpQlg5d4AaABAg',
#   'video_id': '0anbxU8AXV4',
#   'comment_text': 'Karthi anna❤️',
#   'comment_author': 'Shijo Varghese',
#   'comment_published': '2023-11-07T12:09:07Z'},
#  {'comment_id': 'UgwBeJWJ1zf2tG_vHzB4AaABAg',
#   'video_id': '8Qc9ZP-ChC0',
#   'comment_text': '❤❤❤❤🎉🎉🎉',
#   'comment_author': 'Sri Ram',
#   'comment_published': '2023-11-07T12:18:57Z'},
#  {'comment_id': 'Ugy4-ARimEODSMtAD6l4AaABAg',
#   'video_id': '8Qc9ZP-ChC0',
#   'comment_text': '⚡',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-07T12:08:09Z'},
#  {'comment_id': 'UgxuMF0NTRZukmlTF3Z4AaABAg',
#   'video_id': '8Qc9ZP-ChC0',
#   'comment_text': 'GOLDEN STAR⭐⭐⭐⭐ Perfect 👌🥰❤edhye title card la use panugaya inii🎉',
#   'comment_author': 'Arvind 360°',
#   'comment_published': '2023-11-07T11:49:43Z'},
#  {'comment_id': 'UgzwKFBq07yUeixodgJ4AaABAg',
#   'video_id': '8Qc9ZP-ChC0',
#   'comment_text': 'Tha patu vera eduna release pannunga da',
#   'comment_author': 'Deena Dhayalan',
#   'comment_published': '2023-11-07T11:30:50Z'},
#  {'comment_id': 'UgzNTHZN9lpdL-kXUZN4AaABAg',
#   'video_id': '8Qc9ZP-ChC0',
#   'comment_text': 'Japan 💥🔥',
#   'comment_author': 'GOWHAR',
#   'comment_published': '2023-11-07T11:24:11Z'},
#  {'comment_id': 'UgxSyVViGfkRGQSliM94AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Thayavu senchu ne padam matum edukadha......😊',
#   'comment_author': 'Shaik abdul Kader',
#   'comment_published': '2023-11-09T21:11:16Z'},
#  {'comment_id': 'UgzJseaQlMHJ08JfY4l4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'On the way kanga kanga kanguva 🎉',
#   'comment_author': 'MAVERICK',
#   'comment_published': '2023-11-09T11:52:57Z'},
#  {'comment_id': 'UgzoA5PbhRQZKmQPn5Z4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Siruthai 💯🔥',
#   'comment_author': 'W Rahul',
#   'comment_published': '2023-11-08T10:52:50Z'},
#  {'comment_id': 'UgyviQhhYdKW3qOkV254AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Appo andha ak sir padam 4',
#   'comment_author': 'Yasir',
#   'comment_published': '2023-11-08T08:14:19Z'},
#  {'comment_id': 'UgyvclK9Y-APuvar_GN4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Kanguva movie epdi irukku nnu paarpom.. 👍👍',
#   'comment_author': 'Ramanujan Venkatesan',
#   'comment_published': '2023-11-08T06:29:43Z'},
#  {'comment_id': 'UgzYD31o0tKJKxPVGkB4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'சூப்பர் படம் சார்',
#   'comment_author': 'Amarjothi R',
#   'comment_published': '2023-11-07T17:57:01Z'},
#  {'comment_id': 'UgwnUHyF6cslGVq0lyZ4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Siva madri mokka director enoda life la pardila na ajith veriyan but avar madri loosu kootttt... pardila',
#   'comment_author': 'LENINEFILMS',
#   'comment_published': '2023-11-07T15:18:51Z'},
#  {'comment_id': 'Ugyrn2V3isT_8gTJvC94AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Karthi be like, nee enna bit pottalum naa sikka matten di',
#   'comment_author': 'Ragh',
#   'comment_published': '2023-11-07T14:42:05Z'},
#  {'comment_id': 'Ugx3bKNYXu5yvnFRaNl4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Super sir but dhayavusenju karthi sir vechu neenga padam panaadheenga Ajith rajini sir paathutom podhum🙏',
#   'comment_author': 'Ashwin Dinesh',
#   'comment_published': '2023-11-07T14:40:55Z'},
#  {'comment_id': 'UgxbACtyenZ5jrNIRVV4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Ella director mm vanthurukaanga manirathnam vanthurukkaaraa..?',
#   'comment_author': 'Apache Arun',
#   'comment_published': '2023-11-07T14:35:44Z'},
#  {'comment_id': 'UgwJsw5EFKnbfVjluKt4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': '👌',
#   'comment_author': 'spunithkumar S',
#   'comment_published': '2023-11-07T13:43:48Z'},
#  {'comment_id': 'UgxGpeyj66LmJpzi1aF4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': '🤍',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-07T12:07:15Z'},
#  {'comment_id': 'Ugx_qIW9Y5nSGxmgKPB4AaABAg',
#   'video_id': 'pP1kP_9k6NU',
#   'comment_text': 'Versatile Actor Karthi💥<br>DILLI🐐💀',
#   'comment_author': 'Maheshwari Murugan',
#   'comment_published': '2023-11-07T11:29:49Z'},
#  {'comment_id': 'Ugy3V6HCveCr_T7AQH94AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Well done Anjana',
#   'comment_author': 'DS10',
#   'comment_published': '2023-11-08T14:36:56Z'},
#  {'comment_id': 'UgyZ1eXhZ9HQazWp7XJ4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Waiting kaithi 2🥵😘',
#   'comment_author': 'Kunchala Kalyan',
#   'comment_published': '2023-11-08T05:41:45Z'},
#  {'comment_id': 'Ugww6G5fx5jyvWLgY_R4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Anchor kelavi 😂😂😂😂',
#   'comment_author': 'Cmart',
#   'comment_published': '2023-11-07T20:06:36Z'},
#  {'comment_id': 'Ugxj9HfN0OvKeGUOJM14AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=27m52s">27:52</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:23:16Z'},
#  {'comment_id': 'UgzEvt1xqllvhbKs1TJ4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=26m44s">26:44</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:22:30Z'},
#  {'comment_id': 'Ugzldd7EsZJRHk9X6Wt4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=25m59s">25:59</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:21:54Z'},
#  {'comment_id': 'UgxQjr7K3FycTXu-esJ4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=19m41s">19:41</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:16:47Z'},
#  {'comment_id': 'UgxjPb_IvAdmq1pnFjN4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=10m30s">10:30</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:05:00Z'},
#  {'comment_id': 'UgwMokhi9a2lXYWe3FZ4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=8m53s">8:53</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:03:42Z'},
#  {'comment_id': 'UgzGZJnuxU0YQazFj6h4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=8m24s">8:24</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:03:20Z'},
#  {'comment_id': 'UgwUgELNDHuSSCxTm9Z4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=C39Jc32iFAQ&amp;t=4m37s">4:37</a>',
#   'comment_author': 'Inspire 4U',
#   'comment_published': '2023-11-07T18:00:32Z'},
#  {'comment_id': 'UgzsTpAL4qswSqG_9IV4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'karthi anna👍',
#   'comment_author': 'Har Haran',
#   'comment_published': '2023-11-07T17:52:55Z'},
#  {'comment_id': 'UgxGY79EtPRxc6Ne2fF4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Karthi Anna big fan Anna 💞💞💞💞',
#   'comment_author': 'Elamaran Iniyan',
#   'comment_published': '2023-11-07T15:53:50Z'},
#  {'comment_id': 'UgzFlkp434r71NyU_Bx4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '😍',
#   'comment_author': 'Krishna Pradeep',
#   'comment_published': '2023-11-07T14:09:44Z'},
#  {'comment_id': 'Ugy9ODUkCaWGZCzcRTN4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'poi jigarthanda promotiona parunga epd panranga ennu',
#   'comment_author': 'vishwa mithran',
#   'comment_published': '2023-11-07T13:55:18Z'},
#  {'comment_id': 'UgyqJZ1TyGmwWpVVlGd4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'why the fcuk sme interview posting all the channells ,anchor kooda change panla',
#   'comment_author': 'vishwa mithran',
#   'comment_published': '2023-11-07T13:54:58Z'},
#  {'comment_id': 'UgzAErGTP5n__5jgUxF4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Karthick is 13 to 14 years older than the anchor still looks very attractive than that anchor . Men age like wine <br>Female age like milk.',
#   'comment_author': 'Yuvraj Msd',
#   'comment_published': '2023-11-07T13:04:41Z'},
#  {'comment_id': 'Ugx0_PVp9li8AazwsR14AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Vc???????',
#   'comment_author': '2 AM',
#   'comment_published': '2023-11-07T10:18:59Z'},
#  {'comment_id': 'UgyKnuQI0caCnpAHY0d4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': 'Super ya.... 👍👍👍👍👍',
#   'comment_author': 'Karnan',
#   'comment_published': '2023-11-07T10:10:54Z'},
#  {'comment_id': 'UgzS3dX8-QwX5AqB_xx4AaABAg',
#   'video_id': 'C39Jc32iFAQ',
#   'comment_text': '❤',
#   'comment_author': 'Sandy Man',
#   'comment_published': '2023-11-07T09:56:36Z'},
#  {'comment_id': 'Ugy862pWGoLkyA3PkGJ4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ivanellam oru Actor ah? Over allatalana aalu',
#   'comment_author': 'Sakthi ',
#   'comment_published': '2023-11-10T08:21:20Z'},
#  {'comment_id': 'Ugz1_qmOZzL34YKhggF4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ranjith anna masssuuuu....Samuga Neethiii....❤',
#   'comment_author': 'kannanselvakumar sk',
#   'comment_published': '2023-11-10T08:15:50Z'},
#  {'comment_id': 'UgwI6haR8LeNPN6tN3B4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Anchor mayiruh maatri react pannuraah',
#   'comment_author': 'Naan Yokkiyan',
#   'comment_published': '2023-11-10T08:04:16Z'},
#  {'comment_id': 'UgwUd356hmbL6FhkSUp4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'True',
#   'comment_author': 'lakshmi mohan',
#   'comment_published': '2023-11-10T08:01:14Z'},
#  {'comment_id': 'UgwuXFOHd3DsJpNzeKd4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Pa ranjith thevi****paiyan',
#   'comment_author': 'All in all azhagaraja 🤣🤣',
#   'comment_published': '2023-11-10T08:00:29Z'},
#  {'comment_id': 'Ugx1jf8BQWlrXlZxD594AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ana ranjith thevadiyapaiyala jathi ilukura antha mari pannatha',
#   'comment_author': 'Aarthi Spicy',
#   'comment_published': '2023-11-10T07:58:34Z'},
#  {'comment_id': 'UgyuvAe3ZSriytqhrMx4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': '❤❤❤❤❤',
#   'comment_author': 'karthi alli',
#   'comment_published': '2023-11-10T06:12:31Z'},
#  {'comment_id': 'Ugz2U1TRvT0cOWEb5Th4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'ஒருத்தர சமுதாயம்த்துக்கு இப்படி சொம்பு தூக்குறதும் ஒரு அடிமைதனம்தான் கார்த்தி &amp;சூர்யா',
#   'comment_author': 'Manikandan Banu',
#   'comment_published': '2023-11-10T05:30:12Z'},
#  {'comment_id': 'UgzTn6WJXVjNeuaqnbd4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Un vaai un uruttu....',
#   'comment_author': 'sathiyarnc',
#   'comment_published': '2023-11-10T04:17:13Z'},
#  {'comment_id': 'UgwBhRd6Z2HNOcI88Gt4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Always Karthi remained as paruthiveeran....',
#   'comment_author': 'RS STICKERS',
#   'comment_published': '2023-11-10T04:16:17Z'},
#  {'comment_id': 'UgwTWi-Gidlxwo5YjzB4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'pa Ranjith = Madras turning point<br>lokesh = kaithi <br>siruthai Siva = siruthai turning point<br>H.Vinoth = dheeran turning point<br>ameer = paruthiveeran massive hit<br>Selva ragavan = ayirathil oruvan classic movie<br><br>Reason behind good movies,  he is assistant director of maniratnam and he reading the script fully',
#   'comment_author': 'kandan vlog',
#   'comment_published': '2023-11-10T03:57:55Z'},
#  {'comment_id': 'UgyXZMEwnUV6Bqh8hjZ4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': '💙',
#   'comment_author': 'Siva Bharathi',
#   'comment_published': '2023-11-10T03:23:49Z'},
#  {'comment_id': 'UgxnPsWjvsS6OXC3rXF4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'அமீர் இல்லையன்றால் நீங்கள் இல்லை',
#   'comment_author': 'Ashokan Sv',
#   'comment_published': '2023-11-10T03:05:29Z'},
#  {'comment_id': 'UgyW5Ft99zj5ban9A7x4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Nadikatha da',
#   'comment_author': 'vijay krishna',
#   'comment_published': '2023-11-10T02:47:50Z'},
#  {'comment_id': 'Ugy0z6jhprJLJMTdp4J4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ameer engaya',
#   'comment_author': 'naga sundar',
#   'comment_published': '2023-11-10T02:44:31Z'},
#  {'comment_id': 'Ugxo35XmRUpHotwubrB4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'All time fav ❤movie 🎥 🍿🥰',
#   'comment_author': 'A.R Anand',
#   'comment_published': '2023-11-10T02:41:10Z'},
#  {'comment_id': 'UgzNFiSjymcaaflN3DJ4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'உங்க அப்பனுக்கு சொல்லு first கார்த்தி... குள்ளன் தான் அப்படினு பத்த நீயுமா....',
#   'comment_author': 'Venkat J',
#   'comment_published': '2023-11-10T02:40:54Z'},
#  {'comment_id': 'Ugy1pUmFrhMB-5a8riB4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Madras nalla movie like irani but international script nu 😂😂 nalla alandhu vidran',
#   'comment_author': 'r3',
#   'comment_published': '2023-11-10T02:38:56Z'},
#  {'comment_id': 'UgxLFupbykbxWSiidKl4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ranjith Brilliant Director &amp; Person ❤',
#   'comment_author': 'Fire waves',
#   'comment_published': '2023-11-10T02:04:03Z'},
#  {'comment_id': 'UgzgWrzo0EVinReSyfV4AaABAg',
#   'video_id': 'KTeIDfl8g6Y',
#   'comment_text': 'Ena veriya thoondura naye Ranjith avana perumaiya pesuran naye',
#   'comment_author': 'VGR Dhamu catering',
#   'comment_published': '2023-11-09T21:53:28Z'},
#  {'comment_id': 'UgzWt3B0I-lv1xUgIhF4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Appavala vantha naaigal Karthik surya',
#   'comment_author': 'harsath',
#   'comment_published': '2023-11-09T12:09:54Z'},
#  {'comment_id': 'UgyvQR2onfcoytJBQFp4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'En Aamir sir eh koopadala',
#   'comment_author': 'jana ram',
#   'comment_published': '2023-11-09T09:22:41Z'},
#  {'comment_id': 'Ugw216lEwBXwcHKxOJh4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'படம் ஊத்திக்கும் கவலபடாத',
#   'comment_author': 'Vadivel Vadi',
#   'comment_published': '2023-11-09T08:11:42Z'},
#  {'comment_id': 'UgzH548TJe3S8zhsHOZ4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'So great words!! Really impressed 🌸',
#   'comment_author': 'Pravin Kumar',
#   'comment_published': '2023-11-08T12:18:45Z'},
#  {'comment_id': 'Ugwmp2ltMfQN4K6M7Bp4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'அமீர் கும் உங்களுக்கும் courtla case இருக்கு னு  ஒரு  stage function ல பீல் பன்னி சொல்லி இருக்கார்...<br><br>அத முடிச்சு ஒண்ணா இருங்க தலைவரே...',
#   'comment_author': 'Quotes Doses',
#   'comment_published': '2023-11-08T12:06:44Z'},
#  {'comment_id': 'UgzXKV8CadbCz7ZVDpJ4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Ippo thanta first time AMIR pera medaila use pannirukan',
#   'comment_author': 'vignesh Babu',
#   'comment_published': '2023-11-08T04:26:23Z'},
#  {'comment_id': 'UgxqS2APYaHwqvPktkN4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Actor karthik brother stage speech so good in tamil 🌹🌹🌹🌺🌺❤️❤️👋👋👋👋👋',
#   'comment_author': 'GOKUL VOICE 🇮🇳',
#   'comment_published': '2023-11-07T17:11:08Z'},
#  {'comment_id': 'UgxNe5yf1u2ruTlGAld4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Edarhukku etha Mathieu pesurathila killadi.  Ivarukku telugue fans than pidikkum.   Ivar film pakka Tamil audience venum.  Big mouth piece.',
#   'comment_author': 'Bharathi Bharathi',
#   'comment_published': '2023-11-07T15:36:06Z'},
#  {'comment_id': 'Ugw7XR3m2HYx6JheFEd4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'But ungalukgu telugu fan thana pidikgum tamil fans ilaye',
#   'comment_author': 'arun pandi',
#   'comment_published': '2023-11-07T09:02:35Z'},
#  {'comment_id': 'UgwNyLveKIYOxumQFMF4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Jailer eyewear',
#   'comment_author': 'Surya Puliyur',
#   'comment_published': '2023-11-07T07:23:58Z'},
#  {'comment_id': 'UgzkEmKCppbNQfHvaT14AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Rubber vaaya',
#   'comment_author': 'Sk',
#   'comment_published': '2023-11-07T03:53:02Z'},
#  {'comment_id': 'UgyTf-E8ot80M0KtIvh4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': '🤍',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-07T01:48:40Z'},
#  {'comment_id': 'Ugz3H1lMb4OBnHyXUuB4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Grattitude its will grow to career 🎉',
#   'comment_author': 'Ahamed Yasin',
#   'comment_published': '2023-11-06T18:46:20Z'},
#  {'comment_id': 'Ugz3U5Epiw_-bMSTD854AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'He is look like allu arjun sir ❤',
#   'comment_author': 'ᴋʀɪsʜ🦋',
#   'comment_published': '2023-11-06T18:29:16Z'},
#  {'comment_id': 'Ugze1M3xFsbNls-Lkhh4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'sir look smart',
#   'comment_author': 'CHITRA RAJESH',
#   'comment_published': '2023-11-06T16:28:02Z'},
#  {'comment_id': 'Ugy569fdl-KU8wMyn1x4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Apram en pa amir aa function ku kupdalaa',
#   'comment_author': 'Babu Selvam',
#   'comment_published': '2023-11-06T15:51:59Z'},
#  {'comment_id': 'UgyU08DB2XLiddd5pqh4AaABAg',
#   'video_id': 'Bwut-Blv9Lo',
#   'comment_text': 'Nadekan',
#   'comment_author': 'Subash N',
#   'comment_published': '2023-11-06T15:43:51Z'},
#  {'comment_id': 'UgxEqrcU4VvDOqp1FRN4AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': 'No other anchors in telugu?',
#   'comment_author': 'pillalu Illu',
#   'comment_published': '2023-11-09T02:12:35Z'},
#  {'comment_id': 'UgzylKKh_Gr9-CeEIb94AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': 'I want to tell karthis dialogue (khaidi)<br>Sattavani bhayamestunda<br>Savunaina edirinchi savali sir ila kaalla meeda padi kaadu',
#   'comment_author': 'Ravi Teja',
#   'comment_published': '2023-11-06T18:46:32Z'},
#  {'comment_id': 'UgwiKAVOXfrtzST38-94AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': 'karthi 🔥🔥🔥',
#   'comment_author': 'rajesh  ravula',
#   'comment_published': '2023-11-06T15:06:05Z'},
#  {'comment_id': 'UgyjZNuvovp7R73WDgF4AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': '❤🔥',
#   'comment_author': 'deepak p',
#   'comment_published': '2023-11-06T14:08:13Z'},
#  {'comment_id': 'UgwrQ8b-_sXbbPHFZjV4AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': '♥️♥️♥️🎊🎊🎉🎊🎉',
#   'comment_author': 'Thomaskutty John Philip',
#   'comment_published': '2023-11-06T13:14:56Z'},
#  {'comment_id': 'UgzfAn1yHvcSJBlTbR14AaABAg',
#   'video_id': 'nvsEamGPTsY',
#   'comment_text': 'Japan Diwali winner',
#   'comment_author': 'Spartan S',
#   'comment_published': '2023-11-06T11:35:01Z'},
#  {'comment_id': 'Ugwmr5VXKdeCjR9peeh4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'A Man With Zero Ego🥹❤️\u200d🩹',
#   'comment_author': 'മംഗലശേരി നീലകണ്ഠൻ',
#   'comment_published': '2023-11-10T08:30:11Z'},
#  {'comment_id': 'UgzsHATcqavXRVEOfVV4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'எதார்த்தமான நடிகர் ஆவார் இது நல்ல இருக்கும்',
#   'comment_author': 'Murugan D',
#   'comment_published': '2023-11-10T08:15:43Z'},
#  {'comment_id': 'Ugx246ISu7EgEmMeHf94AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Ore kadavul surya anna only ❤❤❤❤❤by surya anna big rasigai ❤❤❤❤❤❤',
#   'comment_author': 'Aarthi Spicy',
#   'comment_published': '2023-11-10T07:50:58Z'},
#  {'comment_id': 'Ugwu6Nxma17II7G8nWF4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'true words. karthi casual ah panraru.veetla epdi irukuraro athe mathiri filmlayum irukaru',
#   'comment_author': 'MTS',
#   'comment_published': '2023-11-10T06:28:58Z'},
#  {'comment_id': 'Ugy_ceb6F4DyVqqgnjF4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Enakku ungalatha putikkum surya😊',
#   'comment_author': 'Suresh Suresh',
#   'comment_published': '2023-11-10T06:27:42Z'},
#  {'comment_id': 'UgxRw93jjrkALqIFbGN4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Nadippu nayagan surya sir mass',
#   'comment_author': 'just entertainment video',
#   'comment_published': '2023-11-10T05:32:52Z'},
#  {'comment_id': 'Ugw0WvkQpdJzT-RCbyR4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'உங்க அண்ணன் தம்பி பாசம் பாக்கும்பொள் எனலுக்கு பொறாமையா இருக்கு...',
#   'comment_author': 'subra mani',
#   'comment_published': '2023-11-10T04:50:45Z'},
#  {'comment_id': 'UgwGdLUyV6cGbAIzCAJ4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'pa Ranjith = Madras turning point<br>lokesh = kaithi <br>siruthai Siva = siruthai turning point<br>H.Vinoth = dheeran turning point<br>ameer = paruthiveeran massive hit<br>Selva ragavan = ayirathil oruvan classic movie<br><br>Reason behind good movies,  he is assistant director of maniratnam and he reading the script fully',
#   'comment_author': 'kandan vlog',
#   'comment_published': '2023-11-10T04:04:25Z'},
#  {'comment_id': 'UgzHP645JY7VPUPpkpx4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Karthi is a good actor. Better than Surya. Surya is overrated',
#   'comment_author': 'Anandhi Arvind',
#   'comment_published': '2023-11-10T03:42:40Z'},
#  {'comment_id': 'UgytX04qACalHraufFt4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Rolex VS Dilli 😅😅😅',
#   'comment_author': 'Ungalnanban_mystery nanban_English',
#   'comment_published': '2023-11-10T03:38:17Z'},
#  {'comment_id': 'Ugx3hqMSneazIR7_YHp4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Spoken like a true brother. This is great example for real life siblings.',
#   'comment_author': 'Bespoke Custom Studio',
#   'comment_published': '2023-11-09T22:41:04Z'},
#  {'comment_id': 'UgxmbMxE-u3S0a5Zrw94AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Thambi&#39;ya???',
#   'comment_author': 'OM PRASATH R',
#   'comment_published': '2023-11-09T22:06:49Z'},
#  {'comment_id': 'UgxDNRYG7A06JPFpIex4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Thozha ,paruthi, paiya,Kadaikutty singam,Dheeran ,siruthai, தம்பி,சுல்தான், viruman my all time favorites of karthi sir the extreme actor',
#   'comment_author': 'maddys world',
#   'comment_published': '2023-11-09T22:02:56Z'},
#  {'comment_id': 'UgyzTkbeTh7CoX_Una94AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': '❤❤❤',
#   'comment_author': 'Periyasamy K RJ',
#   'comment_published': '2023-11-09T21:56:41Z'},
#  {'comment_id': 'UgxXAWQZsmG58050sRV4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Karthi best❣️',
#   'comment_author': 'sanjay san',
#   'comment_published': '2023-11-09T21:02:47Z'},
#  {'comment_id': 'UgymEvDESXypptk_VeZ4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Semaa❤❤❤',
#   'comment_author': 'Muralidharan Appu',
#   'comment_published': '2023-11-09T20:41:37Z'},
#  {'comment_id': 'UgzlmFewIPwK1o298l94AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Surya ❤',
#   'comment_author': 'prakash vish',
#   'comment_published': '2023-11-09T19:34:12Z'},
#  {'comment_id': 'UgwQj3b5c6InQgE1kAl4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Karthik is the only actor giving his best for sure uruttungada',
#   'comment_author': 'Sivabalan T',
#   'comment_published': '2023-11-09T18:45:22Z'},
#  {'comment_id': 'UgwrADUjrJEnmf2d9Jl4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Actually as well as surya doing nandha as well as ayan same perazhagan ,,, different aadhavan,,,pithamagan character surya also  very natural actoru know',
#   'comment_author': '(idanm)',
#   'comment_published': '2023-11-09T18:15:52Z'},
#  {'comment_id': 'UgyOvjaZozZ773SzgyB4AaABAg',
#   'video_id': 'TFO_4FFzUbY',
#   'comment_text': 'Very nice hair transplant',
#   'comment_author': 'weirdo',
#   'comment_published': '2023-11-09T18:10:05Z'},
#  {'comment_id': 'UgxwAECVfUDTaqoEiBt4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Thangalaan movieku wait pannum rasikarkal sarpaka japan vetri pera valthukal',
#   'comment_author': 'Mohammad Mohammad',
#   'comment_published': '2023-11-09T20:23:19Z'},
#  {'comment_id': 'Ugx6U8zcRmGP-Y7B68d4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Bava chelladurai❤❤❤❤❤❤❤❤',
#   'comment_author': 'Thirumurugan',
#   'comment_published': '2023-11-09T16:06:09Z'},
#  {'comment_id': 'Ugx_mqWcVn5-re7_49l4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Bava sir idhu nala dhan BB vitu veliye vandhuteengla',
#   'comment_author': 'MADRAS VICKY',
#   'comment_published': '2023-11-08T17:04:14Z'},
#  {'comment_id': 'Ugw9KpCaawsvv_CDcoR4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Gv prakash kumar Musical 💥🥵',
#   'comment_author': 'GV PRAKASH VERIYAN',
#   'comment_published': '2023-11-07T07:49:26Z'},
#  {'comment_id': 'UgyNFCDYhDptlbi4H4p4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'One of the underrated music director GV Prakash 💥',
#   'comment_author': 'XF [THOR] YT',
#   'comment_published': '2023-11-06T18:34:08Z'},
#  {'comment_id': 'Ugxot5ldLTp9Gg87vxp4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Makapa and Priyanka is the best anchor pair',
#   'comment_author': 'MARAN',
#   'comment_published': '2023-11-06T16:42:08Z'},
#  {'comment_id': 'Ugz6eKalZfsicF1FzAd4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Editor philomin anna 😂😂😂😂',
#   'comment_author': 'S.U.S CREATION',
#   'comment_published': '2023-11-06T15:46:16Z'},
#  {'comment_id': 'UgyPnbcRGoA3EF45LIR4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': '❤🔥',
#   'comment_author': 'deepak p',
#   'comment_published': '2023-11-06T12:16:16Z'},
#  {'comment_id': 'UgyQHDoIgZhCJ6Hqip14AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Karthi sir koopdri😡😡<br>Anu emannuel loosu',
#   'comment_author': 'wazeeM',
#   'comment_published': '2023-11-06T12:05:59Z'},
#  {'comment_id': 'UgzqZ4pJd5B6WEiMxVh4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Come back Bigg Boss Pradeep',
#   'comment_author': 'NITHIESH KATHIRAVAN',
#   'comment_published': '2023-11-06T11:01:49Z'},
#  {'comment_id': 'Ugyx8ymRuDSwXZvCEKJ4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'DILLI WILL RETURN🔥🥵🔥',
#   'comment_author': 'Black Devil',
#   'comment_published': '2023-11-06T10:19:58Z'},
#  {'comment_id': 'UgxsTdxNkJ1uDC8oU2x4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'Big fan \U0001faad u kt',
#   'comment_author': 'g KrishN ',
#   'comment_published': '2023-11-06T09:50:37Z'},
#  {'comment_id': 'UgwW6GAwSDKZy7rwpwB4AaABAg',
#   'video_id': 'qz1Idbyw8t8',
#   'comment_text': 'THANKYOU GUYS FOR YOUR LOVE AND SUPPORT ❤',
#   'comment_author': 'Actor Vijay Official Fans ',
#   'comment_published': '2023-11-06T09:46:02Z'},
#  {'comment_id': 'UgwAQH23mmj0Af544zB4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Thangalaan movieku wait pannum rasikarkal sarpaka japan vetri perum,karthi,raju,gv and japan teamku valthukal',
#   'comment_author': 'Mohammad Mohammad',
#   'comment_published': '2023-11-09T20:19:35Z'},
#  {'comment_id': 'Ugwh8D102yDAoS1oMdN4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Highly intellectual  is Rajumurugan sir',
#   'comment_author': 'Panchavarnam Manimegalai',
#   'comment_published': '2023-11-09T07:36:20Z'},
#  {'comment_id': 'UgzpNlM7EMLWi9wguGR4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Director RajuMurugan is known to me as a thinking    writer. I read his writings  whenever  I  get  the material',
#   'comment_author': 'Panchavarnam Manimegalai',
#   'comment_published': '2023-11-09T07:33:46Z'},
#  {'comment_id': 'UgwQwK3UbOqHFGJVfQR4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Gypsy ♥️🔥🔥🔥',
#   'comment_author': 'youtube tamilan',
#   'comment_published': '2023-11-09T04:44:14Z'},
#  {'comment_id': 'UgyRuE0CCALU7NZZ1ax4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Sr prabu look like hero.clear speech super',
#   'comment_author': 'anand kumar',
#   'comment_published': '2023-11-07T20:41:09Z'},
#  {'comment_id': 'UgyxE3nfuJUupVa2eKV4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Raju murugan sir kkum karthi sirkkum jappan movie teamukkum intha padam periya vetriyake vazhthkrinen 🙂👍 engalkk thrillinganathum nalla valuesum irkkra padam paatha experience kedaykkattum. 😍🙂🤩',
#   'comment_author': 'M CM',
#   'comment_published': '2023-11-07T12:03:35Z'},
#  {'comment_id': 'UgzMUd-bfy6WGMsgPTh4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Enga ooru Rajumurugan Anna padam vetripera valthugal Anna',
#   'comment_author': 'MUKESH ABIVAI',
#   'comment_published': '2023-11-07T05:27:10Z'},
#  {'comment_id': 'UgyUjZlUDeyZJwG36uJ4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Congrats my dear brother raju murugan 🎉',
#   'comment_author': 'Sathish divya Sathish divya',
#   'comment_published': '2023-11-07T04:00:57Z'},
#  {'comment_id': 'UgyRWA7WL0DnEhgS7rN4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Vallthukal team Sfcdxb',
#   'comment_author': 'ZioM.s 876',
#   'comment_published': '2023-11-06T18:37:37Z'},
#  {'comment_id': 'Ugxg5Ufv-xbKdQaAW594AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': '👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍',
#   'comment_author': 'Karnan',
#   'comment_published': '2023-11-06T13:01:41Z'},
#  {'comment_id': 'UgzjjFbGyFcc1KXwm_F4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': '❤🎉',
#   'comment_author': 'Arya Ramachandhran',
#   'comment_published': '2023-11-06T11:20:34Z'},
#  {'comment_id': 'UgwFyZbmmw7GZ_qQ3bh4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Clap and whistle sound mattum tha kekuthu ana umaiya  yarum adikala 😂',
#   'comment_author': 'Madhesh',
#   'comment_published': '2023-11-06T11:18:27Z'},
#  {'comment_id': 'UgzFpz6u9A8Bfk1adEl4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Love You Raju Murugan Sir See You Soon ❤❤❤❤',
#   'comment_author': 'Praveen Archu',
#   'comment_published': '2023-11-06T10:52:31Z'},
#  {'comment_id': 'UgxlXXXwLNlmFgpDwxF4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'ராஜு முருகன் 🔥',
#   'comment_author': 'Suresh Kumar',
#   'comment_published': '2023-11-06T10:34:04Z'},
#  {'comment_id': 'Ugw9YbPrs6-rdCtc1Dd4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': 'Unmaiyana writing iruntha podhum sir❤ sila Peru padathula olunga kaatama interviewla fake nu soli 😂 emathuranga',
#   'comment_author': 'Bala',
#   'comment_published': '2023-11-06T10:26:28Z'},
#  {'comment_id': 'Ugz6BD95KfY_joMHhSh4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': '❤❤❤',
#   'comment_author': 'Yasar Arafath',
#   'comment_published': '2023-11-06T09:52:45Z'},
#  {'comment_id': 'Ugznej1rbbbPa7ezM5x4AaABAg',
#   'video_id': 'ZquI0eJO9aI',
#   'comment_text': '👇Thalapathy Vijay fans here',
#   'comment_author': 'Actor Vijay Official Fans ',
#   'comment_published': '2023-11-06T09:45:37Z'},
#  {'comment_id': 'UgyNsQzP9eHdIl4fvEh4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'KF ultra.. but i like Budwieser magnum',
#   'comment_author': 'Jithin Joseph',
#   'comment_published': '2023-11-09T17:56:33Z'},
#  {'comment_id': 'UgwvgCcTn21tw1Ikjpx4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'Micham eduna paatu irukka illaya da eduna release pannunga da mada samburaningala',
#   'comment_author': 'Deena Dhayalan',
#   'comment_published': '2023-11-07T15:10:36Z'},
#  {'comment_id': 'UgxDvixTPMy2BQM2Q0d4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'ஏண்டா ஜப்பானியர்கள் உழைப்புக்கு  பெயர்பெற்றவர்கள்.அந்த பெயரை ஒரு பொறம்போக்கு கதாபாத்திரத்திற்கு வச்சுருக்கீங்களே , ஏண்டா இப்படி. இதுவே நம் நான்டின் பெயரையோ அல்லது சுதந்திர போராட்ட தியாகிகளின் பெயரை மற்றவர்கள் இதுபோல் வைத்தால் வானத்துக்கும் பூமிக்கும் குதிக்குரிங்கள்ள .அப்போ நாம் எப்படி நடந்துக்கணும் நீ என்ன பண்ணிவச்சுருக்க...<br>*****தா நீங்கலாம்  படம் எடுக்கலைனு யாரு அழுதா.',
#   'comment_author': 'vijay sarathi',
#   'comment_published': '2023-11-07T06:15:51Z'},
#  {'comment_id': 'Ugz8oUtbAEo9MUnQmEN4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': '😍😍😍',
#   'comment_author': 'Thomaskutty John Philip',
#   'comment_published': '2023-11-06T17:40:06Z'},
#  {'comment_id': 'UgwO63mgstK9sczIW694AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'Mass movie 🎉',
#   'comment_author': 'Subash N',
#   'comment_published': '2023-11-06T15:39:33Z'},
#  {'comment_id': 'UgwYVTXr1-PJH3R3uDN4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': '⚡',
#   'comment_author': 'Adithyan Cm',
#   'comment_published': '2023-11-06T15:00:54Z'},
#  {'comment_id': 'Ugw9zsKeqPSI9V7HpW54AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'Kandipa padam hit blockbuster hit anna ❤😂🎉🎉🎉',
#   'comment_author': 'Santhosh Kumar',
#   'comment_published': '2023-11-06T12:29:59Z'},
#  {'comment_id': 'Ugy6e8DxATcYBZdLW8x4AaABAg',
#   'video_id': 'UtJcpHAG5Qk',
#   'comment_text': 'Flop',
#   'comment_author': 'GOKUL ANAND VENKATESWARAN',
#   'comment_published': '2023-11-06T11:33:08Z'},
#  {'comment_id': 'UgzOFOLdMdJ37WtSKR54AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'Sam C.S❤',
#   'comment_author': 'Nagen Pugunes',
#   'comment_published': '2023-11-10T08:27:34Z'},
#  {'comment_id': 'UgwxrcP06gJwDwvtwYt4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'Kaithi 2 ku Sam C S venum',
#   'comment_author': 'Vijay',
#   'comment_published': '2023-11-10T07:43:55Z'},
#  {'comment_id': 'UgxrliBAPln9cxE_SUF4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'But the scene in real hero The goat Sam CS 🔥',
#   'comment_author': 'Asuran_Isai_Kulu',
#   'comment_published': '2023-11-10T06:39:07Z'},
#  {'comment_id': 'Ugy0YtQhF6eokQHMDRd4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'Pundaya muditu kelambu',
#   'comment_author': 'Black man',
#   'comment_published': '2023-11-10T06:16:33Z'},
#  {'comment_id': 'UgwQJcJkMtEvHiqCysB4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'Idhu Japan movie kka illa kaithikka ...😮karthikku kaithi bench mark ...vilayaatupulla😅',
#   'comment_author': 'Nellai_Gamer',
#   'comment_published': '2023-11-10T06:10:34Z'},
#  {'comment_id': 'UgzU8GjWF0yY6XKBoxZ4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'Sam c.s dha main athula',
#   'comment_author': 'Yogeshwaran Muthukrishnan',
#   'comment_published': '2023-11-10T05:59:41Z'},
#  {'comment_id': 'UgxsYzAOefCOcfyNV6R4AaABAg',
#   'video_id': '43QEX5jcrSs',
#   'comment_text': 'C.S Sam ❤ Bgm',
#   'comment_author': 'Rolls Royce',
#   'comment_published': '2023-11-10T05:19:01Z'},
#  {'comment_id': 'UgxidC5QZRNYFvuhAHt4AaABAg',
#   'video_id': '43QEX5jcrSs',
# ...
#   'comment_author': 'spunithkumar S',
#   'comment_published': '2023-11-06T15:28:40Z'},
#  {'comment_id': 'UgwzehpS2IMK1W3azCZ4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'The star craze in cinema should come to an end. All great movies are made by directors who had no pressure to make a movie for a star.<br><br>The director/writer should be given his own time to write and prepare for a movie. One cannot write a strong script with a deadline given by the star&#39;s call sheet.',
#   'comment_author': 'Guna Sekaran',
#   'comment_published': '2023-10-29T10:44:42Z'},
#  {'comment_id': 'Ugwyo1gJZTC61OMLkpl4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Yow h vinoth intha padam innamu payama irukiya 😢 nee vera level ya.. screenplays la bangam pannita ❤🎉',
#   'comment_author': 'Nothing Myself',
#   'comment_published': '2023-10-20T11:35:29Z'},
#  {'comment_id': 'Ugw5hwr58psSeqyc-zp4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'H vinod ippudi apdam edukanum Thalapathy Vijay ku 🔥🔥🔥🔥',
#   'comment_author': 'Anish K Anish',
#   'comment_published': '2023-10-20T10:26:52Z'},
#  {'comment_id': 'UgxTgzR3eujzIipf2E54AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'one of the best tamil flim.',
#   'comment_author': 'Anish K Anish',
#   'comment_published': '2023-10-20T10:26:23Z'},
#  {'comment_id': 'UgyAJPxDlEYQZlcKUj14AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Super film ennaku pudikum',
#   'comment_author': 'Prabha M',
#   'comment_published': '2023-10-17T17:19:47Z'},
#  {'comment_id': 'UgzbzFtbqFbOZ0c4B9l4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'I would say the best movie of karthi',
#   'comment_author': 'Mani Vijay',
#   'comment_published': '2023-10-08T18:07:30Z'},
#  {'comment_id': 'Ugz10BqGDT2g_iJKVmp4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Part 2 please!!!',
#   'comment_author': 'Shanthi Shunmugam',
#   'comment_published': '2023-09-26T14:37:24Z'},
#  {'comment_id': 'UgwUFLa2D_OmKUt5hrl4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Movie na ipadi irukanum',
#   'comment_author': 'PNS',
#   'comment_published': '2023-09-24T13:56:52Z'},
#  {'comment_id': 'UgySIN35yrwNejs_PBF4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'அது என்ன மாயமோ மந்திரமோ தெரியல இந்த படத்த அடிகடி பார்த்த மட்டும் சலிக்கவே மாட்டது😊❤',
#   'comment_author': 'MuruganSandy',
#   'comment_published': '2023-09-24T07:14:25Z'},
#  {'comment_id': 'UgzJuevCWQmcN_qb-hp4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Karthi anna fabulous ❤',
#   'comment_author': 'S Akshaya',
#   'comment_published': '2023-08-16T03:49:48Z'},
#  {'comment_id': 'UgwqreXw6AetdegwAst4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Maass❤️❤️❤️',
#   'comment_author': 'spunithkumar S',
#   'comment_published': '2023-08-14T06:35:31Z'},
#  {'comment_id': 'UgxjK8qGn5oaDIr3uYp4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Still remember getting goosebumps watching this movie in theatre <br>These are those films which u go with less excpectation but come out with fulfill ment watching a master piece',
#   'comment_author': 'Manoj Pandian',
#   'comment_published': '2023-08-09T19:22:16Z'},
#  {'comment_id': 'Ugy6ILp0So09if5m2lV4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'You should give come back with kh233 movie with Kamal Hassan',
#   'comment_author': 'Gnanaraj',
#   'comment_published': '2023-08-06T23:09:45Z'},
#  {'comment_id': 'UgyQcRBIs6Fa5EAXaPt4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'மாஸ் சின்',
#   'comment_author': 'Vishnumoorth Moorthy',
#   'comment_published': '2023-07-29T14:10:07Z'},
#  {'comment_id': 'UgwlYxlhqK4TEtAVilh4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'அ.வினோத் சம்பவம்❤',
#   'comment_author': 'Endrum Suriya Rasigan',
#   'comment_published': '2023-07-29T07:24:25Z'},
#  {'comment_id': 'UgwWg62zYuINDrm9hwF4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Real story 🎉 tamilnadu police good job good police not recognised always 😢',
#   'comment_author': 'Adhavan A',
#   'comment_published': '2023-07-17T01:33:41Z'},
#  {'comment_id': 'UgxOl6c85ldCg0jvtrZ4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'வேற லெவல் தமிழ் படம்<br>தீரன் அதிகாரம் ஒன்று<br>✨️❤️😇🙏🏽🥺🙏🏽😇❤️✨️',
#   'comment_author': 'Sangkar Mogan',
#   'comment_published': '2023-07-16T16:11:17Z'},
#  {'comment_id': 'UgzQXfWY9sGk4Mi4A6Z4AaABAg',
#   'video_id': 'sG7YjTmXiFI',
#   'comment_text': 'Pondaigila verum 74 comments intha video ku ga  otha full pannuga',
#   'comment_author': 'Kasi Kasi kaala',
#   'comment_published': '2023-07-16T15:19:00Z'},
#  {'comment_id': 'UgyUe5d5yyEiXtAlC_J4AaABAg',
#   'video_id': 'OnsKyP787dQ',
#   'comment_text': '<a href="http://www.youtube.com/results?search_query=%23lcu">#LCU</a> fans pls forward 🔥',
#   'comment_author': 'Vimal Varghese',
#   'comment_published': '2023-04-17T11:57:24Z'},
#  {'comment_id': 'Ugw1IBYxLb35gH4Vh-N4AaABAg',
#   'video_id': 'OnsKyP787dQ',
#   'comment_text': 'First',
#   'comment_author': 'aaroshan rajarajeswaran',
#   'comment_published': '2023-04-17T09:14:35Z'},
#  {'comment_id': 'UgyeNvJdLTmf0GKLzxR4AaABAg',
#   'video_id': 'RwM1-2Gbry0',
#   'comment_text': 'Nice',
#   'comment_author': 'Abdul Nasir Nssir',
#   'comment_published': '2023-04-16T06:19:21Z'},
#  {'comment_id': 'UgzCm80ciXNUPqPGUCR4AaABAg',
#   'video_id': 'LzW97N0halc',
#   'comment_text': 'Karthi movies are always special... 🎉🎉🎉',
#   'comment_author': 'Subramanian anbazhagan',
#   'comment_published': '2023-08-03T17:35:59Z'},
#  {'comment_id': 'UgxZB0eBBSTyG7czAH94AaABAg',
#   'video_id': 'iSZipS7cgMk',
#   'comment_text': 'One and only word for this scene and the entire movie is...<br>MASTERPIECE!',
#   'comment_author': 'Nicholas J',
#   'comment_published': '2023-10-23T17:24:01Z'},
#  {'comment_id': 'UgyX9EnBDq1byr2R2Ml4AaABAg',
#   'video_id': 'iSZipS7cgMk',
#   'comment_text': '✌🏻',
#   'comment_author': '𝚊𝚋𝚑𝚒𝚕𝚊𝚜𝚑',
#   'comment_published': '2023-04-24T20:21:26Z'},
#  {'comment_id': 'UgyFnJ6_1ffAyXoNK-Z4AaABAg',
#   'video_id': 'yujEjcy_1j0',
#   'comment_text': 'MASSSSSS',
#   'comment_author': 'reuben george',
#   'comment_published': '2023-04-10T21:45:08Z'},
#  {'comment_id': 'UgxjgWXDOYhzaiXMSaJ4AaABAg',
#   'video_id': 'MoBpf-QveFA',
#   'comment_text': 'Waiting for kaithi 2🙋\u200d♂️',
#   'comment_author': 'linoj',
#   'comment_published': '2023-04-10T01:44:02Z'},
#  {'comment_id': 'Ugz-C1dZKhhe7ZwyN_d4AaABAg',
#   'video_id': 'dnV1UK9FXqQ',
#   'comment_text': 'Mass ❤ from Sri Lanka 🇱🇰 🇱🇰 🇱🇰',
#   'comment_author': 'aaa',
#   'comment_published': '2023-04-09T03:05:08Z'},
#  {'comment_id': 'UgybbXxtKntiy12w9Op4AaABAg',
#   'video_id': 'uzv-yIiOuK4',
#   'comment_text': 'What&#39;s her character name?',
#   'comment_author': 'Nini__.07',
#   'comment_published': '2023-11-03T06:06:54Z'},
#  {'comment_id': 'UgwcqzVCjqpTIHoekhF4AaABAg',
#   'video_id': 'uzv-yIiOuK4',
#   'comment_text': '😍',
#   'comment_author': 'Sanjayraj mahendran',
#   'comment_published': '2023-04-10T14:11:56Z'},
#  {'comment_id': 'UgwVlpb3nAXw6B5Fx-54AaABAg',
#   'video_id': 'WvWe3mjiwEE',
#   'comment_text': 'Excited!!',
#   'comment_author': 'Aysha Musthaq',
#   'comment_published': '2023-04-07T21:41:57Z'},
#  {'comment_id': 'UgyV8Nd0uK8KULOcI2B4AaABAg',
#   'video_id': 'WvWe3mjiwEE',
#   'comment_text': 'dev mohan lucky fellow.. always gets top heroines',
#   'comment_author': 'Abhishek RC',
#   'comment_published': '2023-04-07T15:07:43Z'},
#  {'comment_id': 'UgyffaMCsHC6_IECw4J4AaABAg',
#   'video_id': 'WvWe3mjiwEE',
#   'comment_text': 'Please show Rashmika beautiful 😇😇😇',
#   'comment_author': 'Rakshan Rishikesh',
#   'comment_published': '2023-04-07T14:52:37Z'},
#  {'comment_id': 'UgxuN4id3mdT9MYyBiB4AaABAg',
#   'video_id': '6doHjZ37QNc',
#   'comment_text': 'Waiting for <a href="http://www.youtube.com/results?search_query=%23kaithi2">#Kaithi2</a> 🔥',
#   'comment_author': 'Theran Hunt-(U)',
#   'comment_published': '2023-04-07T12:43:43Z'},
#  {'comment_id': 'UgwROqgBnlftjDooClx4AaABAg',
#   'video_id': 'K1-CcpqvLDo',
#   'comment_text': 'Dubbed malayalam',
#   'comment_author': 'BLACK FRIDAY',
#   'comment_published': '2023-04-03T16:08:15Z'},
#  {'comment_id': 'UgzCUpaQbKvT0SI6zut4AaABAg',
#   'video_id': 'K1-CcpqvLDo',
#   'comment_text': '🎉🎉❤',
#   'comment_author': 'Sanjayraj mahendran',
#   'comment_published': '2023-04-03T14:55:19Z'},
#  {'comment_id': 'UgzJ_Ywd-wmlUsARKoJ4AaABAg',
#   'video_id': 'K1-CcpqvLDo',
#   'comment_text': 'Rashu 😊❤❤❤',
#   'comment_author': 'Sanjayraj mahendran',
#   'comment_published': '2023-04-03T14:55:09Z'},
#  {'comment_id': 'UgxuZ1UC3psftrspES14AaABAg',
#   'video_id': 'K1-CcpqvLDo',
#   'comment_text': 'Rashmika❤',
#   'comment_author': 'SP',
#   'comment_published': '2023-04-03T14:21:32Z'},
#  {'comment_id': 'Ugz-L3A5wjxLLAPlMAV4AaABAg',
#   'video_id': 'K1-CcpqvLDo',
#   'comment_text': 'Congratulations🎉🎊',
#   'comment_author': 'Galaxy Properties',
#   'comment_published': '2023-04-03T13:14:00Z'},
#  {'comment_id': 'UgwnagG47wAa1FrnpOx4AaABAg',
#   'video_id': 'gv1mYoV_eA4',
#   'comment_text': 'Semma BGM',
#   'comment_author': 'Never Give Up',
#   'comment_published': '2023-05-09T18:53:27Z'},
#  {'comment_id': 'Ugx0fQ8ZjdclqsETIXd4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': '💃💃💃💃💃🤨🤨🤨',
#   'comment_author': 'Rosnra',
#   'comment_published': '2023-10-14T05:16:16Z'},
#  {'comment_id': 'UgzL-xPVPoExKyHhkPN4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': '😂😂😂😂😂😂😂😂',
#   'comment_author': 'Akash MSR',
#   'comment_published': '2023-07-26T08:53:03Z'},
#  {'comment_id': 'UgzwkmXsXrjg325eDH94AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': '❤Heart beating 💓💞🥰🥰',
#   'comment_author': 'RY318 Heart Beating',
#   'comment_published': '2023-07-07T16:39:17Z'},
#  {'comment_id': 'UgwYFNSQiNHmXEPP4Et4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'I love you Karthik Anna ❤',
#   'comment_author': 'S Akshaya',
#   'comment_published': '2023-07-07T11:04:14Z'},
#  {'comment_id': 'UgxSfmwOtsNJI59fJAR4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'Miss u mano Bala sir',
#   'comment_author': 'Gowsalya G',
#   'comment_published': '2023-05-30T10:25:43Z'},
#  {'comment_id': 'Ugy7o2AsKTdI3JapxQt4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'வெளிநாடு போய் படிச்சு வந்ததும் அப்பா தொழில், இதுக்கு பருத்தி கிடவுன்லே இருந்து இருக்கலாம்.',
#   'comment_author': 'Siva Prakash.R',
#   'comment_published': '2023-05-21T11:49:56Z'},
#  {'comment_id': 'UgxtbR4dDwx0SijLxcl4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'We Always Miss You Mr.Manobala Sir 😢😢',
#   'comment_author': 'Iethgash Narayanan Barathan',
#   'comment_published': '2023-05-20T02:22:13Z'},
#  {'comment_id': 'UgzD-y_iHIv9suRjtdR4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'Miss you sir 😢',
#   'comment_author': 'Kiru Kiru',
#   'comment_published': '2023-05-19T14:34:54Z'},
#  {'comment_id': 'UgwTPIIGgNKjG97Qg7t4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'We miss you Mano bala sir',
#   'comment_author': 'thilagavathi thilagavathi',
#   'comment_published': '2023-05-18T06:13:55Z'},
#  {'comment_id': 'UgzuYULUOZh0qZMwhQZ4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'Haha',
#   'comment_author': 'த. கௌசல்யா தேவி',
#   'comment_published': '2023-05-14T02:59:15Z'},
#  {'comment_id': 'Ugy3yWgpF62f5tEM42F4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': '😄😄😄😄😄😄😄😄',
#   'comment_author': 'Chandra sekaran Chandra sekaran',
#   'comment_published': '2023-05-11T06:12:42Z'},
#  {'comment_id': 'UgzSNddYkzBWdsW101Z4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'Miss u mano Bala ayya 😢',
#   'comment_author': 'Sabari nathan',
#   'comment_published': '2023-05-09T12:20:29Z'},
#  {'comment_id': 'UgxmzL_26kQB93f7VJZ4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'What’s the name of this movie’s',
#   'comment_author': 'Jaya Srinivasan',
#   'comment_published': '2023-05-06T16:50:39Z'},
#  {'comment_id': 'Ugy1CiExjU11nabHE0F4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'my favourite movie and songs🥰🥰🥰🥰',
#   'comment_author': 'bharani raj',
#   'comment_published': '2023-03-30T05:02:59Z'},
#  {'comment_id': 'UgzbEPvbZemXzDC0xZp4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': 'Comedy',
#   'comment_author': 'Bhakti special',
#   'comment_published': '2023-03-22T20:16:51Z'},
#  {'comment_id': 'Ugx8yRmQqvAB_WaXBZd4AaABAg',
#   'video_id': 'pEOIZyHLANA',
#   'comment_text': '😙😔😙😙💙💙💙💙💙💗💗💗👌👌👌👌👌👌👌👌👌👌👌👌👌👌',
#   'comment_author': 'Mum Taj',
#   'comment_published': '2023-03-22T15:21:55Z'},
#  {'comment_id': 'UgyaqT-jSWoRNo9BtIV4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Hope you all are enjoying <a href="http://www.youtube.com/results?search_query=%23sulthanost">#SulthanOST</a> :)',
#   'comment_author': 'Dream Warrior Pictures',
#   'comment_published': '2023-03-06T07:46:38Z'},
#  {'comment_id': 'UgwS79SEbCFaMkk4wpx4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'U1...... 🔥💥',
#   'comment_author': 'Billa Tamil',
#   'comment_published': '2023-09-03T10:26:32Z'},
#  {'comment_id': 'UgxGNLySoSErH4cqJMN4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Yuvan is bgm king but you gave this chance to Vivek mervin',
#   'comment_author': 'Kalavathy M',
#   'comment_published': '2023-05-29T08:54:30Z'},
#  {'comment_id': 'UgweF3hWWOeIt7-pn8V4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Summa therilka vitturukkan bgm yuvan yuvan vitu bgm povadhu bgm yuvan vittu povadhu',
#   'comment_author': '3DD UNIVERSE',
#   'comment_published': '2023-05-02T16:24:48Z'},
#  {'comment_id': 'Ugyz0Ew8UQL5Z50UVUJ4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Tamil hd video songs uploaded sir pls letast movies',
#   'comment_author': 'Natural babys talking',
#   'comment_published': '2023-03-29T01:53:49Z'},
#  {'comment_id': 'UgxXW6Zog7zYbVRVnMR4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'In hindi',
#   'comment_author': 'The_roamer_boy',
#   'comment_published': '2023-03-20T08:39:34Z'},
#  {'comment_id': 'UgyoM3A1ECTJAx83skx4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'U1💙',
#   'comment_author': 'Sakthi',
#   'comment_published': '2023-03-16T06:02:49Z'},
#  {'comment_id': 'Ugw3l70liRaBV8IKURl4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=65YRhnw6lHc&amp;t=16m43s">16:43</a> peak moment🥵',
#   'comment_author': 'A   N   A   TROLZ&CUTZ',
#   'comment_published': '2023-03-13T08:51:40Z'},
#  {'comment_id': 'UgzIiPHe_3RQh5lSuYJ4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=65YRhnw6lHc&amp;t=2m26s">2:26</a> Goosebumps 💥🔥🥵',
#   'comment_author': 'Jerry Shanelee',
#   'comment_published': '2023-03-06T17:29:31Z'},
#  {'comment_id': 'UgwThjyTpFQ2bj50Kzd4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': '🔥🔥🔥',
#   'comment_author': 'Paiyaa Naveen',
#   'comment_published': '2023-03-06T16:15:31Z'},
#  {'comment_id': 'Ugwvg0I_iqq9M__fYSF4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=65YRhnw6lHc&amp;t=12m54s">12:54</a> Arrival of Demon <br>Antha Demon ee Yuvan Thaanda🥵🥵🔥',
#   'comment_author': 'Anjith Kumar A',
#   'comment_published': '2023-03-06T14:23:31Z'},
#  {'comment_id': 'UgzeDWslCh2vkonCD1Z4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Yuvan',
#   'comment_author': 'StarVersatile',
#   'comment_published': '2023-03-06T07:48:04Z'},
#  {'comment_id': 'Ugx5Se-Y8E9mPCtD4G54AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Attend Yuvan Squad here 🔥',
#   'comment_author': 'Yugan Moorthy',
#   'comment_published': '2023-03-06T06:30:16Z'},
#  {'comment_id': 'UgwR6yaaL2aHZ8PerEp4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Yuvan sir yuvan anthe',
#   'comment_author': 'Vijay Kumar',
#   'comment_published': '2023-03-05T13:11:29Z'},
#  {'comment_id': 'UgxWX6UmiRCBNm6iEIl4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': 'Neraya bgm missing in this OST',
#   'comment_author': 'Mathiyamudhan S',
#   'comment_published': '2023-03-05T09:57:33Z'},
#  {'comment_id': 'UgxH7mXo8c-oMVntwOR4AaABAg',
#   'video_id': '65YRhnw6lHc',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=65YRhnw6lHc&amp;t=6m40s">6:40</a> 🥵😤',
#   'comment_author': 'Mathiyamudhan S',
#   'comment_published': '2023-03-05T09:49:26Z'},
#  ...]

# %%
len(comment_details)
# Out:
# 2629

# %%
# getting playlist info
def getting_playlist_details(channel_id):

    next_page_token=None
    playlist_info=[]
    while True:
        request=youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token


        )

        response=request.execute()

        for item in response['items']:
            data=dict(playlist_Id=item['id'],
                    playlist_title=item['snippet']['title'],
                    channel_id=item['snippet']['channelId'],
                    channel_name=item['snippet']['channelTitle'],
                    channel_published=item['snippet']['publishedAt'],
                    video_count=item['contentDetails']['itemCount'])
            playlist_info.append(data)

        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return playlist_info

# %%
playlist_details=getting_playlist_details('UCbpjEr8lHlnkf1SQ5tnDEYw')

# %%
len(playlist_details)
# Out:
# 34

# %%
# connecting mongodb

client=pymongo.MongoClient("mongodb+srv://rjsound7:sowntharya@cluster0.eku2p1c.mongodb.net/?retryWrites=true&w=majority")
db=client['youtube_data']

# %%
def channel_details(channel_id):
     ch_details=getting_ch_id(channel_id)
     pl_details=getting_playlist_details(channel_id)
     vi_ids=getting_video_id(channel_id)
     vi_details=getting_video_info(vi_ids)
     com_details=getting_comment_info(vi_ids)

     coll1=db['channel_details']
     coll1.insert_one({'channel_information':ch_details,'playlist_information':pl_details,
                       'video_information':vi_details,'comment_information':com_details})
     

     return 'upload completed successfully'

# %%
insert=channel_details('UCf0KybguYN3FqbRoxCbR6kw')

# %%
insert
# Out:
# 'upload completed successfully'

# %%
# table creation
def channels_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='sowntharya',
                        database='youtube_data',
                        port='5432')

    cursor=mydb.cursor()

    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(channel_name varchar(100),
                                                            channel_id varchar(80) primary key,
                                                            subscription_count bigint,
                                                            channel_views bigint,
                                                            Total_videos int,
                                                            channel_description text,
                                                            playlist_id varchar(80)
                                                            )'''
        cursor.execute(create_query)
        mydb.commit()

    except:
        st.write('channel table created')


    ch_list=[]
    db=client['youtube_data']
    coll1=db['channel_details']
    for ch_data in coll1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    df=pd.DataFrame(ch_list)


    for index,row in df.iterrows():
        insert_query='''INSERT into channels(channel_name,
                                            channel_id,
                                            subscription_count,
                                            channel_views,
                                            Total_videos,
                                            channel_description,
                                            playlist_id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['channel_name'],
                row['channel_id'],
                row['subscription_count'],
                row['channel_views'],
                row['Total_videos'],
                row['channel_description'],
                row['playlist_id'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            st.write('channels rows and values are inserted')

# %%
# playlst table
def playlist_table():

    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='sowntharya',
                        database='youtube_data',
                        port='5432')

    cursor=mydb.cursor()

    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists playlists(playlist_Id varchar(100) primary key,
                                                            playlist_title varchar(100) ,
                                                            channel_id varchar(100),
                                                            channel_name varchar(100),
                                                            channel_published timestamp,
                                                            video_count int
                                                            )'''
        cursor.execute(create_query)
        mydb.commit()
    except:
        st.write('Playlist table created already')

    
    db=client['youtube_data']
    coll1=db['channel_details']
    pl_list=[]
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])

    df1=pd.DataFrame(pl_list)

    
    for index,row in df1.iterrows():
        insert_query='''INSERT into playlists(playlist_Id,
                                            playlist_title,
                                            channel_id,
                                            channel_name,
                                            channel_published,
                                            video_count)
                                            
                                            values(%s,%s,%s,%s,%s,%s)'''
        values=(row['playlist_Id'],
                row['playlist_title'],
                row['channel_id'],
                row['channel_name'],
                row['channel_published'],
                row['video_count'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            st.write('playlists rows and values are inserted')

# %%
def videos_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='sowntharya',
                        database='youtube_data',
                        port='5432')

    cursor=mydb.cursor()

    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()
    
    try:


        create_query='''create table if not exists videos(Channel_name varchar(100),
                            channel_id varchar(100),
                            video_Id varchar(50) primary key,
                            title varchar(200),
                            tags text,
                            thumbnail varchar(200),
                            description text,
                            published_date timestamp,
                            duration interval,
                            view_count bigint,
                            likes bigint,
                            comments int,
                            favourite_count int,
                            caption_status varchar(50),
                            definition varchar(50)
                                                            )'''
        cursor.execute(create_query)
        mydb.commit()

    except:
        st.write('videos table created already')

# %%
vi_list=[]
db=client['youtube_data']
coll1=db['channel_details']
for vi_data in coll1.find({},{'_id':0,'video_information':1}):
    for i in range(len(vi_data['video_information'])):
        vi_list.append(vi_data['video_information'][i])

df2=pd.DataFrame(vi_list)

# %%
df2
# Out:
#                                                       0
# 0                                           b_Www6uU-vk
# 1                                           W-22k_NnX80
# 2                                           LTEN9p7loFE
# 3                                           MD57rLYcbZY
# 4                                           EQc-s2GS1k4
# ...                                                 ...
# 1021  {'Channel_name': 'U1 Records', 'channel_id': '...
# 1022  {'Channel_name': 'U1 Records', 'channel_id': '...
# 1023  {'Channel_name': 'U1 Records', 'channel_id': '...
# 1024  {'Channel_name': 'U1 Records', 'channel_id': '...
# 1025  {'Channel_name': 'U1 Records', 'channel_id': '...
#
# [1026 rows x 1 columns]

# %%
for index,row in df2.iterrows():
        insert_query='''INSERT INTO videos(channel_name, 
                    channel_id,
                    video_Id,
                    title,
                    tags,
                    thumbnail,
                    description,
                    published_date,
                    duration,
                    view_count,
                    likes,
                    comments,
                    favourite_count,
                    caption_status,
                    definition)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['channel_name'],
                row['channel_id'],
                row['video_Id'],
                row['title'],
                row['tags'],
                row['thumbnail'],
                row['description'],
                row['published_date'],
                row['duration'],
                row['view_count'],
                row['likes'],
                row['comments'],
                row['favourite_count'],
                row['caption_status'],
                row['definition'])
        
                 
        try:
        
                cursor.execute(insert_query,values)
                mydb.commit()
        except:
                st.write('video values are inserted already')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\divya\Music\virtual envi\youtubetest.ipynb Cell 31 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> for index,row in df2.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a>         insert_query='''INSERT INTO videos(channel_name,
#       <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a>                     channel_id,
#       <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a>                     video_Id,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=16'>17</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=17'>18</a>                                             values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
# ---> <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=18'>19</a>         values=(row['channel_name'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=19'>20</a>                 row['channel_id'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=20'>21</a>                 row['video_Id'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=21'>22</a>                 row['title'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=22'>23</a>                 row['tags'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=23'>24</a>                 row['thumbnail'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=24'>25</a>                 row['description'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=25'>26</a>                 row['published_date'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=26'>27</a>                 row['duration'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=27'>28</a>                 row['view_count'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=28'>29</a>                 row['likes'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=29'>30</a>                 row['comments'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=30'>31</a>                 row['favourite_count'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=31'>32</a>                 row['caption_status'],
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=32'>33</a>                 row['definition'])
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=35'>36</a>         try:
#      <a href='vscode-notebook-cell:/c%3A/Users/divya/Music/virtual%20envi/youtubetest.ipynb#X45sZmlsZQ%3D%3D?line=37'>38</a>                 cursor.execute(insert_query,values)
#
# File c:\Users\divya\Music\virtual envi\.venv\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\divya\Music\virtual envi\.venv\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\divya\Music\virtual envi\.venv\Lib\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'channel_name'

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
# comment table
def comments_table():
    mydb=psycopg2.connect(host='localhost',
                        user='postgres',
                        password='sowntharya',
                        database='youtube_data',
                        port='5432')

    cursor=mydb.cursor()

    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()


    create_query='''create table if not exists comments(comment_id varchar(100) primary key,
                            video_id varchar(50),
                            comment_text text,
                            comment_author varchar(150),
                            comment_published timestamp
                            )'''
    cursor.execute(create_query)
    mydb.commit()

    try:
        create_query = '''CREATE TABLE if not exists comments(comment_id varchar(100) primary key,
                       video_id varchar(80),
                       comment_text text, 
                       comment_author varchar(150),
                       comment_published timestamp)'''
        cursor.execute(create_query)
        mydb.commit()
        
    except:
        st.write("Comment Table created already")

# %%
com_list=[]
db=client['youtube_data']
coll1=db['channel_details']
for com_data in coll1.find({},{'_id':0,'comment_information':1}):
    for i in range(len(com_data['comment_information'])):
        com_list.append(com_data['comment_information'][i])

df3=pd.DataFrame(com_list)

# %%
df3
# Out:
#                       comment_id     video_id  \
# 0     UgwAzepc4Vn2MH6gNgN4AaABAg  W5tLw-aGlfY
# 1     Ugxofhw3Qs2h2yTqRel4AaABAg  W5tLw-aGlfY
# 2     UgwioQQr6gOLzHUyKvt4AaABAg  W5tLw-aGlfY
# 3     UgyYHTeLdFHWrukwuiZ4AaABAg  W5tLw-aGlfY
# 4     Ugw34vntjFRmoyev7pR4AaABAg  W5tLw-aGlfY
# ...                          ...          ...
# 2237  Ugyu4OBCImTKh4dYWt94AaABAg  8K3AxMgXxIY
# 2238  UgymBCZSzHo5poxEWnB4AaABAg  8K3AxMgXxIY
# 2239  UgxldL8rajBfalxwsDl4AaABAg  8K3AxMgXxIY
# 2240  UgxFV8USOeYRw1GCEJF4AaABAg  8K3AxMgXxIY
# 2241  UgyTfIJ5uxdJadmI8hl4AaABAg  8K3AxMgXxIY
#
#                                            comment_text  \
# 0                                    U1 fans hit like ❤
# 1                                         Best director
# 2                                             Utterflop
# 3     Movie la யுவன் anna music Vera level ah irukum...
# 4     WAITING FOR U1 RECENT SONGS ARE IRRITATING FRO...
# ...                                                 ...
# 2237  Am here commenting in all the videos only for ...
# 2238                                             Super.
# 2239                                        Good song!!
# 2240                                        Good lyrics
# 2241                        Woww Melodious Srisha Sissy
#
#                comment_author     comment_published
# 0                 anupama S S  2023-11-10T08:31:44Z
# 1              கோகுல் G சேனல்  2023-11-10T08:18:49Z
# 2                        Vj27  2023-11-10T07:10:45Z
# 3                Tamil Neethi  2023-11-10T06:02:42Z
# 4             venkatesh kumar  2023-11-09T17:42:36Z
# ...                       ...                   ...
# 2237              Surya Speak  2020-02-03T06:28:46Z
# 2238        Monikaa's channel  2020-02-02T15:49:18Z
# 2239  Malarvannan Subramanian  2020-01-27T04:14:12Z
# 2240        Ganapathy Kailash  2020-01-23T18:17:59Z
# 2241               KarthicK G  2020-01-23T01:45:10Z
#
# [2242 rows x 5 columns]

# %%
for index,row in df3.iterrows():
        insert_query='''INSERT INTO comments(comment_id,
                        video_id,
                        comment_text,
                        comment_author,
                        comment_published)
                                            
                                            values(%s,%s,%s,%s,%s)'''
        values=(row['comment_id'],
                row['video_id'],
                row['comment_text'],
                row['comment_author'],
                row['comment_published']
                )
        
        try:
                cursor.execute(insert_query,values)
                mydb.commit()
        except:
                st.write('comment are already exists')

# %%
# CREATING ALL TABLES
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return 'tables created successfully'

# %%
def view_channels_table():
    ch_list=[]
    db=client['youtube_data']
    coll1=db['channel_details']
    for ch_data in coll1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    channels_table=st.dataframe(ch_list)

    return channels_table

# %%
def view_playlists_table():
    pl_list=[]
    db=client['youtube_data']
    coll1=db['channel_details']
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])

    playlist_table=st.dataframe(pl_list)

    return playlist_table

# %%
def view_videos_table():
    vi_list=[]
    db=client['youtube_data']
    coll2=db['channel_details']
    for vi_data in coll2.find({},{'_id':0,'video_information':1}):
        for i in range(len(vi_data['video_information'])):
            vi_list.append(vi_data['video_information'][i])

    videos_table=st.dataframe(vi_list)

    return videos_table

# %%
def view_comments_table():
    com_list=[]
    db=client['youtube_data']
    coll3=db['channel_details']
    for com_data in coll3.find({},{'_id':0,'comment_information':1}):
        for i in range(len(com_data['comment_information'])):
            com_list.append(com_data['comment_information'][i])

    comment_table=st.dataframe(com_list)

    return comment_table

# %%
# streamlit
with st.sidebar:
    st.title('red:[YOUTUBE DATA HARVESTING]')
    st.header('OVWERVIEW')
    st.caption('Data collected from youtube channels')
    st.caption('API Key')
    st.caption('Coded through Python Language')
    st.caption('Datas stored in Mongob')
    st.caption('Tables created and created as SQL')
    st.caption('showcasing through Streamlit UI')
    
channel_id= st.text_input('Enter the channel id')
channels=channel_id.split(',')
channels=[ch.strip() for ch in channels if ch]

if st.button('collect and store data'):
    for channel in channels:
        ch_ids=[]
        db=client['youtube_data']
        coll1=db[channel_details]
        for ch_data in coll1.find({},{'_id':0,channel_information:1}):
            ch_ids.append(ch_data['channel_information']['channel_id'])
            
        if channel_id in ch_ids:
            st.success('channel id ' + channel + 'already exists')
        else:
            insert=channel_details(channel)
            st.success(output)
            
            
if st.button('Migrate to sql'):
    display=tables()
    st.success(display)
    
show_table=st.radio('SELECT THE TABLES',(':blue[channels]',':red[playlists]',':green[videos]',':black[comments]'))

if show_table==':blue[channels]':
    view_channels_table()
    
elif show_table==':red[playlists]':
    view_playlists_table()
    
elif show_table==':green[videos]':
    view_videos_table()
    
elif show_table==':black[comments]':
    view_comments_table()

# %%
# sql connection
mydb=psycopg2.connect(host='localhost',
                    user='postgres',
                    password='sowntharya',
                    database='youtube_data',
                    port='5432')
cursor=mydb.cursor()

question=st.selectbox('Select your question',
                      ('1. All the videos and channel names',
                                              '2. Channels with most no.of videos',
                                              '3. Top 10 most viewed videos',
                                              '4. Comments in each video',
                                              '5. videos with highest likes ',
                                              '6. Likes of all videos',
                                              '7. views of each channels',
                                              '8. videos published on 2022'
                                              '9. Average duration of all videos in channels',
                                              '10. Videos with highest no.of. comments'))

# %%
if question == '1. All the videos and the Channel Name':
    query1 = "select Title as videos, Channel_Name as ChannelName from videos;"
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    st.write(pd.DataFrame(t1, columns=["Video Title","Channel Name"]))

elif question == '2. Channels with most number of videos':
    query2 = "select Channel_Name as ChannelName,Total_Videos as NO_Videos from channels order by Total_Videos desc;"
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    st.write(pd.DataFrame(t2, columns=["Channel Name","No Of Videos"]))

elif question == '3. 10 most viewed videos':
    query3 = '''select Views as views , Channel_Name as ChannelName,Title as VideoTitle from videos 
                        where Views is not null order by Views desc limit 10;'''
    cursor.execute(query3)
    mydb.commit()
    t3 = cursor.fetchall()
    st.write(pd.DataFrame(t3, columns = ["views","channel Name","video title"]))

elif question == '4. Comments in each video':
    query4 = "select Comments as No_comments ,Title as VideoTitle from videos where Comments is not null;"
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    st.write(pd.DataFrame(t4, columns=["No Of Comments", "Video Title"]))

elif question == '5. Videos with highest likes':
    query5 = '''select Title as VideoTitle, Channel_Name as ChannelName, Likes as LikesCount from videos 
                       where Likes is not null order by Likes desc;'''
    cursor.execute(query5)
    mydb.commit()
    t5 = cursor.fetchall()
    st.write(pd.DataFrame(t5, columns=["video Title","channel Name","like count"]))

elif question == '6. likes of all videos':
    query6 = '''select Likes as likeCount,Title as VideoTitle from videos;'''
    cursor.execute(query6)
    mydb.commit()
    t6 = cursor.fetchall()
    st.write(pd.DataFrame(t6, columns=["like count","video title"]))

elif question == '7. views of each channel':
    query7 = "select Channel_Name as ChannelName, Views as Channelviews from channels;"
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    st.write(pd.DataFrame(t7, columns=["channel name","total views"]))

elif question == '8. videos published in the year 2022':
    query8 = '''select Title as Video_Title, Published_Date as VideoRelease, Channel_Name as ChannelName from videos 
                where extract(year from Published_Date) = 2022;'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    st.write(pd.DataFrame(t8,columns=["Name", "Video Publised On", "ChannelName"]))

elif question == '9. average duration of all videos in each channel':
    query9 =  "SELECT Channel_Name as ChannelName, AVG(Duration) AS average_duration FROM videos GROUP BY Channel_Name;"
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    t9 = pd.DataFrame(t9, columns=['ChannelTitle', 'Average Duration'])
    T9=[]
    for index, row in t9.iterrows():
        channel_title = row['ChannelTitle']
        average_duration = row['Average Duration']
        average_duration_str = str(average_duration)
        T9.append({"Channel Title": channel_title ,  "Average Duration": average_duration_str})
    st.write(pd.DataFrame(T9))

elif question == '10. videos with highest number of comments':
    query10 = '''select Title as VideoTitle, Channel_Name as ChannelName, Comments as Comments from videos 
                       where Comments is not null order by Comments desc;'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    st.write(pd.DataFrame(t10, columns=['Video Title', 'Channel Name', 'NO Of Comments']))
